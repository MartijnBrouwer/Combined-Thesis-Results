# %% [markdown]
# # Creating bifurcation diagrams and Lyapunov exponent plots of the logistic map, Lorenz system and Mackey Glass time series

# %% [markdown]
# # Combined Bachelor Thesis (NS-320B), June 2022
# ## Mathematics & Physics and Astronomy
# *'Applying Physics-informed Neural Networks to Chaotic Systems of Ordinary Differential Equations'*
#
# **Author:** Martijn Sebastiaan Brouwer (6859488)
#
# **Mathematics supervisors:** prof. dr. ir. C.W. Oosterlee
#
# **Physics supervisor:** dr. J. de Graaf
#
# **PhD supervisor:** B. Negyesi

# %% [markdown]
# # Bifurcation diagram and Lyapunov exponents of the logistic map: $x_{n+1}=rx_n(1-x_n)$.

# %%
import numpy as np
import matplotlib.pyplot as plt

#Definition of the logistic map -----------------------------------------------
def logistic_map(r, x): return r*x*(1 - x)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)
plt.subplots_adjust(hspace=0)
n = 5000
r = np.linspace(2.8, 4, n)
iterations = 1000
x = (1e-6)*np.ones(n) #n-dimensional array containing the initial condition
lyapunov = np.zeros(n) #Lyapunov exponents start at 0

for i in range(iterations):
    lyapunov += np.log(abs(r - 2*r*x)) #Lyapunov exp. is defined as the scaled sum of the logs of the derivative of the equation.
    x = logistic_map(r, x) #Update current x_list

    if i >= iterations - 100: #For each of these last 100 iterations, the resulting stabilities are plotted
        ax1.plot(r, x, ',k', alpha=.1)

ax1.set_xlim(min(r),max(r))
ax1.set_ylim(0,1)
ax1.set_ylabel("$x_n$", fontsize="xx-large")
ax1.axvline(3, color='k', lw=.5, alpha=.5)
ax1.axvline(3.4494, color='k', lw=.5, alpha=.5)
ax1.axvline(3.541988397679536, color='k', lw=.5, alpha=.5)
ax1.axvline(3.57, color='r', lw=.5, alpha=.5)
ax1.axvline(3.828365673134627, color='k', lw=.5, alpha=.5)
ax1.annotate("(a)",xy=(-0.11, 0.95),xycoords='axes fraction',fontsize="xx-large",color="k")

ax2.plot(r[lyapunov < 0], lyapunov[lyapunov <= 0]/iterations, '.k', alpha=.5, ms=.5) #Lyapunov exponents should still be scaled with the iterations (more is better)
ax2.plot(r[lyapunov >= 0], lyapunov[lyapunov > 0]/iterations, '.r', alpha=.5, ms=.5) #Chaotic regime
ax2.set_ylim(-2, 1.2)
ax2.set_xlabel("$r$", fontsize="xx-large")
ax2.set_ylabel("Lyapunov exponent $\\lambda(r)$", fontsize="xx-large")
ax2.set_xlim(min(r),max(r))
ax2.annotate("(1)",xy=(0.07, 0.9),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("(2)",xy=(0.34, 0.9),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("(3)",xy=(0.565, 0.9),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("(4)",xy=(0.725, 0.9),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("(5)",xy=(0.91, 0.9),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("$r_H$",xy=(0.63, -0.09),xycoords='axes fraction',fontsize="x-large",color="k")
ax2.annotate("(b)",xy=(-0.11, 0.95),xycoords='axes fraction',fontsize="xx-large",color="k")
ax2.axhline(0, color='r', lw=.5, alpha=.5)
ax2.axvline(3, color='k', lw=.5, alpha=.5)
ax2.axvline(3.4494, color='k', lw=.5, alpha=.5)
ax2.axvline(3.541988397679536, color='k', lw=.5, alpha=.5)
ax2.axvline(3.57, color='r', lw=.5, alpha=.5)
ax2.axvline(3.828365673134627, color='k', lw=.5, alpha=.5)
plt.savefig('logistic_bifurcation.png', dpi=200)
plt.show()

# Plot of the chaotic regime in which the windows of periodicity are visible ---
x = (1e-6)*np.ones(n)
for i in range(iterations):
    x = logistic_map(r, x)
    if i >= iterations - 100:
        plt.plot(r, x, ',k', alpha=.1)
plt.xlim(3.57,max(r))
plt.ylim(0,1)
plt.xlabel("$r$", fontsize="xx-large")
plt.ylabel("$x_n$", fontsize="xx-large")
plt.axvline(3.57, color='r', lw=.5, alpha=.5)
plt.axvline(3.63, color='r', lw=.5, alpha=.5)
plt.axvline(3.74, color='r', lw=.5, alpha=.5)
plt.axvline(3.828365673134627, color='r', lw=.5, alpha=.5)
plt.savefig('windows_of_periodicity.png')
plt.show()

# Plot of a single line to show the behaviour of the stabilities ---------------
n = 10000
x = (1e-6)*np.ones(n)
r = np.linspace(0, 4, n)
for i in range(iterations):
    x = logistic_map(r, x)
    if i == iterations - 100: #Thus only x_{900}
        plt.plot(r, x, ',k', alpha=.1)
plt.xlim(min(r),max(r))
plt.ylim(0,1)
plt.xlabel("$r$", fontsize="xx-large")
plt.ylabel("$x_{900}$", fontsize="xx-large")
plt.axvline(3.57, color='r', lw=.5, alpha=.5)
plt.annotate("$r_H$",xy=(0.88, -0.13),xycoords='axes fraction',fontsize="x-large",color="k")
plt.savefig('single_line.png')
plt.show()

# %% [markdown]
# # Bifurcation diagram and Lyapunov exponents of the Lorenz system.

# %%
import numpy as np
import matplotlib.pyplot as plt

def RungeKutta(dxdt,dydt,dzdt, x0,y0,z0, tf,n):
    h = tf/n
    xl,yl,zl = n*[0],n*[0],n*[0]
    xl[0],yl[0],zl[0] = x0,y0,z0
    for i in range(1,n):
        x,y,z = xl[i-1],yl[i-1],zl[i-1]

        k1x,k1y,k1z = (h*f(x,y,z)    for f in (dxdt,dydt,dzdt))
        xs,ys,zs    = (r + 0.5*kr    for r,kr in zip((x,y,z),(k1x,k1y,k1z,h)))
        k2x,k2y,k2z = (h*f(xs,ys,zs) for f in (dxdt,dydt,dzdt))
        xs,ys,zs    = (r + 0.5*kr    for r,kr in zip((x,y,z),(k2x,k2y,k2z,h)))
        k3x,k3y,k3z = (h*f(xs,ys,zs) for f in (dxdt,dydt,dzdt))
        xs,ys,zs    = (r + kr        for r,kr in zip((x,y,z),(k3x,k3y,k3z,h)))
        k4x,k4y,k4z = (h*f(xs,ys,zs) for f in (dxdt,dydt,dzdt))
        
        xl[i],yl[i],zl[i] = (r + (k1r + 2*k2r + 2*k3r + k4r)/6 for r,k1r,k2r,k3r,k4r in 
                zip((x,y,z),(k1x,k1y,k1z),(k2x,k2y,k2z),(k3x,k3y,k3z),(k4x,k4y,k4z)))
    return xl,yl,zl

def dxdt(x,y,z): return -sigma*x + sigma*y
def dydt(x,y,z): return -x*z + rho*x - y
def dzdt(x,y,z): return x*y - beta*z

def Lorenz(x0,y0,z0, sigma,rho,beta, tf,steps):
    x,y,z = RungeKutta(dxdt,dydt,dzdt, x0,y0,z0, tf,steps)
    return x,y,z

n = 10000
iterations = 350000
sigma,beta = 10,8/3
h = 0.001
tf = h*iterations
rho_max = 350
rho = np.arange(0, rho_max, rho_max/n)
x,y,z = np.ones(n),np.ones(n),np.ones(n) #list with correct shape and initial conditions
lyapunov_x,lyapunov_y,lyapunov_z = np.zeros(n),np.zeros(n),np.zeros(n)

def plotting():
    fig = plt.figure(figsize=(13,4))
    ax = fig.add_subplot(1, 3, 1)
    ax.axhline(0, color='r', lw=.5, alpha=.5)
    ax.plot(rho[lyapunov_x < 0], lyapunov_x[lyapunov_x < 0]/iterations, '.k', alpha=.5, ms=.5)
    ax.plot(rho[lyapunov_x >= 0], lyapunov_x[lyapunov_x >= 0]/iterations, '.r', alpha=.5, ms=.5)
    ax.set_xlim(min(rho), max(rho))
    ax.set_ylim(-50, 10)
    ax.set_xlabel('$\\rho$', fontsize="x-large")
    ax.set_ylabel('Lyapunov exponent of  $x$', fontsize="x-large")

    ax = fig.add_subplot(1, 3, 2)
    ax.axhline(0, color='r', lw=.5, alpha=.5)
    ax.plot(rho[lyapunov_y < 0], lyapunov_y[lyapunov_y < 0]/iterations, '.k', alpha=.5, ms=.5)
    ax.plot(rho[lyapunov_y >= 0], lyapunov_y[lyapunov_y >= 0]/iterations, '.r', alpha=.5, ms=.5)
    ax.set_xlim(min(rho), max(rho))
    ax.set_ylim(-50, 10)
    ax.set_xlabel('$\\rho$', fontsize="x-large")
    ax.set_ylabel('Lyapunov exponent of $y$', fontsize="x-large")

    ax = fig.add_subplot(1, 3, 3)
    ax.axhline(0, color='r', lw=.5, alpha=.5)
    ax.plot(rho[lyapunov_z < 0], lyapunov_z[lyapunov_z < 0]/iterations, '.k', alpha=.5, ms=.5)
    ax.plot(rho[lyapunov_z >= 0], lyapunov_z[lyapunov_z >= 0]/iterations, '.r', alpha=.5, ms=.5)
    ax.set_xlim(min(rho), max(rho))
    ax.set_ylim(-50, 10)
    ax.set_xlabel('$\\rho$', fontsize="x-large")
    ax.set_ylabel('Lyapunov exponent of $z$', fontsize="x-large")
    plt.tight_layout()
    plt.savefig('Lyapunov_exp.png')
    plt.show()

for i in range(iterations):
    k1x,k1y,k1z = h*dxdt(x,y,z),h*dydt(x,y,z),h*dzdt(x,y,z)
    k2x,k2y,k2z = h*dxdt(x+k1x/2,y+k1y/2,z+k1z/2),h*dydt(x+k1x/2,y+k1y/2,z+k1z/2),h*dzdt(x+k1x/2,y+k1y/2,z+k1z/2)
    k3x,k3y,k3z = h*dxdt(x+k2x/2,y+k2y/2,z+k2z/2),h*dydt(x+k2x/2,y+k2y/2,z+k2z/2),h*dzdt(x+k2x/2,y+k2y/2,z+k2z/2)
    k4x,k4y,k4z = h*dxdt(x+k3x,y+k3y,z+k3z),h*dydt(x+k3x,y+k3y,z+k3z),h*dzdt(x+k3x,y+k3y,z+k3z)
    x,y,z = x+(k1x+2*k2x+2*k3x+k4x)/6,y+(k1y+2*k2y+2*k3y+k4y)/6,z+(k1z+2*k2z+2*k3z+k4z)/6

    lyapunov_x += np.log(abs(-sigma*x + sigma*y))
    lyapunov_y += np.log(abs(-x*z + rho*x - y))
    lyapunov_z += np.log(abs(x*y - beta*z))

rho_list = np.arange(0, rho_max, rho_max/n)
x0,y0,z0 = 1,1,1
rx_maxes,x_maxes,rx_mins,x_mins = [],[],[],[]
ry_maxes,y_maxes,ry_mins,y_mins = [],[],[],[]
rz_maxes,z_maxes,rz_mins,z_mins = [],[],[],[]
for rho in rho_list:
    print('Current rho:', rho)
    x,y,z = Lorenz(x0,y0,z0, sigma,rho,beta, tf,n)
    x,y,z = np.array(x),np.array(y),np.array(z)
    for i in range(1, len(z) - 1):
        if x[i - 1] < x[i] and x[i] > x[i + 1]:         # save the local maxima
            rx_maxes.append(rho)
            x_maxes.append(x[i])
        elif x[i - 1] > x[i] and x[i] < x[i + 1]:       # save the local minima
            rx_mins.append(rho)
            x_mins.append(x[i])
        
        if y[i - 1] < y[i] and y[i] > y[i + 1]:         # save the local maxima
            ry_maxes.append(rho)
            y_maxes.append(y[i])
        elif y[i - 1] > y[i] and y[i] < y[i + 1]:       # save the local minima
            ry_mins.append(rho)
            y_mins.append(y[i])

        if z[i - 1] < z[i] and z[i] > z[i + 1]:         # save the local maxima
            rz_maxes.append(rho)
            z_maxes.append(z[i])
        elif z[i - 1] > z[i] and z[i] < z[i + 1]:       # save the local minima
            rz_mins.append(rho)
            z_mins.append(z[i])
        
        x0,y0,z0 = x[i],y[i],z[i]

fig = plt.figure(figsize=(13,4))
plt.subplots_adjust(hspace=0)
ax = fig.add_subplot(1, 3, 1)
ax.scatter(rx_maxes, x_maxes, color="r", s=0.5, alpha=0.1)
ax.scatter(rx_mins, x_mins, color="k", s=0.5, alpha=0.1)
ax.set_xlim(min(rho_list), max(rho_list))
ax.set_ylabel('$x$', fontsize="x-large")
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.axvline(470/19, color='r', lw=.5, alpha=.5)
ax.annotate("$\\rho_H$",xy=(0.05, -0.09),xycoords='axes fraction',fontsize="x-large",color="k")

ax = fig.add_subplot(1, 3, 2)
ax.scatter(ry_maxes, y_maxes, color="r", s=0.5, alpha=0.1)
ax.scatter(ry_mins, y_mins, color="k", s=0.5, alpha=0.1)
ax.set_xlim(min(rho_list), max(rho_list))
ax.set_ylabel('$y$', fontsize="x-large")
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.axvline(470/19, color='r', lw=.5, alpha=.5)
ax.annotate("$\\rho_H$",xy=(0.05, -0.09),xycoords='axes fraction',fontsize="x-large",color="k")

ax = fig.add_subplot(1, 3, 3)
ax.scatter(rz_maxes, z_maxes, color="r", s=0.5, alpha=0.1)
ax.scatter(rz_mins, z_mins, color="k", s=0.5, alpha=0.1)
ax.set_xlim(min(rho_list), max(rho_list))
ax.set_ylabel('$z$', fontsize="x-large")
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.axvline(470/19, color='r', lw=.5, alpha=.5)
ax.annotate("$\\rho_H$",xy=(0.05, -0.09),xycoords='axes fraction',fontsize="x-large",color="k")
plt.tight_layout()
plt.savefig('Bifurcation_diagram.png')
plt.show()

fig = plt.figure(figsize=(13,4))
ax = fig.add_subplot(1, 3, 1)
ax.axhline(0, color='r', lw=.5, alpha=.5)
ax.plot(rho[lyapunov_x < 0], lyapunov_x[lyapunov_x < 0]/iterations, '.k', alpha=.5, ms=.5)
ax.plot(rho[lyapunov_x >= 0], lyapunov_x[lyapunov_x >= 0]/iterations, '.r', alpha=.5, ms=.5)
ax.set_xlim(min(rho), max(rho))
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.set_ylabel('Lyapunov exponent of  $x$', fontsize="x-large")

ax = fig.add_subplot(1, 3, 2)
ax.axhline(0, color='r', lw=.5, alpha=.5)
ax.plot(rho[lyapunov_y < 0], lyapunov_y[lyapunov_y < 0]/iterations, '.k', alpha=.5, ms=.5)
ax.plot(rho[lyapunov_y >= 0], lyapunov_y[lyapunov_y >= 0]/iterations, '.r', alpha=.5, ms=.5)
ax.set_xlim(min(rho), max(rho))
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.set_ylabel('Lyapunov exponent of $y$', fontsize="x-large")

ax = fig.add_subplot(1, 3, 3)
ax.axhline(0, color='r', lw=.5, alpha=.5)
ax.plot(rho[lyapunov_z < 0], lyapunov_z[lyapunov_z < 0]/iterations, '.k', alpha=.5, ms=.5)
ax.plot(rho[lyapunov_z >= 0], lyapunov_z[lyapunov_z >= 0]/iterations, '.r', alpha=.5, ms=.5)
ax.set_xlim(min(rho), max(rho))
ax.set_xlabel('$\\rho$', fontsize="x-large")
ax.set_ylabel('Lyapunov exponent of $z$', fontsize="x-large")
plt.tight_layout()
plt.savefig('Lyapunov_exp2.png')
plt.show()

# %% [markdown]
# # Bifurcation diagram of the Mackey Glass time series

# %%
# expected runtime: 2u 50m 34s
import numpy as np
import matplotlib.pyplot as plt

def RungeKutta(dxdt, x0, tf, n): #Specify derivatives, initial conditions and time
    h = tf/n   #Stepsize
    xl = n*[0] #Create lists for output
    xl[0] = x0 #First element in outputlist is initial condition
    for i in range(1,n): #Loop over steps while skipping the first one due to the initial condition
        x_t = xl[i-1]
        if i-1 >= n/tf*tau: #Determining the delation time
            x_t_minus_tau = xl[int(i-1-n/tf*tau)]
        else: 
            x_t_minus_tau = 0 #The dilation term 

        #Going through the four RK4 equations:
        k1x = h*dxdt(x_t, x_t_minus_tau)
        xs  = x_t + 0.5*k1x
        xs_minus_tau = x_t_minus_tau + 0.5*k1x
        k2x = h*dxdt(xs, xs_minus_tau)
        xs  = x_t + 0.5*k2x  
        xs_minus_tau = x_t_minus_tau + 0.5*k2x
        k3x = h*dxdt(xs, xs_minus_tau)
        xs  = x_t + k3x
        xs_minus_tau = x_t_minus_tau + k3x
        k4x = h*dxdt(xs, xs_minus_tau)
        #Update last next value in output list:
        xl[i] = x_t + (k1x + 2*k2x + 2*k3x + k4x)/6 
    return xl

# Mackey Glass time series DE -------------------------------------------------
def MG(x_t, x_t_minus_tau):
    return a*x_t_minus_tau/(1 + x_t_minus_tau**10) - b*x_t

def Mackey_Glass(MG, x0, a,b,tau, tf,steps):
    x = RungeKutta(MG, x0, tf, steps)
    return x


# =============================================================================
# ================= Bifurcation diagram over varying tau ======================
# =============================================================================
# Parameters ------------------------------------------------------------------
x0  = 0.1              #Initial conditions
a,b = 0.2,0.1          #Parameters of the system
ti  = 0                #Initial time
tf  = 100              #Final time
tau_max = 40           #Maximum tau value
steps = 25000          #Steps between each tau
tau_list = np.arange(0, tau_max, tau_max/steps)
tx_maxes,x_maxes,tx_mins,x_mins = [],[],[],[]
for tau in tau_list:
    print('Current tau:', tau)
    x = Mackey_Glass(MG, x0, a,b,tau, tf,steps)
    x = np.array(x)
    for i in range(1, len(x) - 1):
        if x[i - 1] < x[i] and x[i] > x[i + 1]:         # saving the local maxima
            tx_maxes.append(tau)
            x_maxes.append(x[i])
        elif x[i - 1] > x[i] and x[i] < x[i + 1]:       # saving the local minima
            tx_mins.append(tau)
            x_mins.append(x[i])
        
        x0 = x[i]

n = 10
C = ((a - b)/b)**(1/n)
F_der = (1 + C**n - n*C**n)/(1+C**n)**2
tau_H = np.arccos(b/(a*F_der))/(np.sqrt((a*F_der)**2-b**2))
print('Hopf_bifurcation value =', tau_H)

plt.figure()
plt.scatter(tx_maxes, x_maxes, color="r", s=0.5, alpha=0.25)
plt.scatter(tx_mins, x_mins, color="k", s=0.5, alpha=0.25)
plt.xlim(min(tau_list), tau_max)
plt.ylim(0,1.5)
plt.ylabel('$P(t)$', fontsize="x-large")
plt.xlabel('$\\tau$', fontsize="x-large")
plt.axvline(tau_H, color='r', lw=0.75, alpha=.5)
plt.annotate("$\\tau_H$",xy=(0.05, -0.09),xycoords='axes fraction',fontsize="x-large",color="k")
plt.savefig('MG_bifurcation.png')
plt.show()


# =============================================================================
# ================== Bifurcation diagram over varying a =======================
# =============================================================================
# Parameters ------------------------------------------------------------------
x0  = 0.1              #Initial conditions
b,tau = 0.1,17         #Parameters of the system
ti  = 0                #Initial time
tf  = 100              #Final time
a_max = 1.5            #Maximum tau value
steps = 25000           #Steps between each tau
a_list = np.arange(0, a_max, a_max/steps)
ax_maxes,x_maxes,ax_mins,x_mins = [],[],[],[]
for a in a_list:
    print('Current a:', a)
    x = Mackey_Glass(MG, x0, a,b,tau, tf,steps)
    x = np.array(x)
    for i in range(1, len(x) - 1):
        if x[i - 1] < x[i] and x[i] > x[i + 1]:         # saving the local maxima
            ax_maxes.append(a)
            x_maxes.append(x[i])
        elif x[i - 1] > x[i] and x[i] < x[i + 1]:       # saving the local minima
            ax_mins.append(a)
            x_mins.append(x[i])
        
        x0 = x[i]

plt.figure()
plt.scatter(ax_maxes, x_maxes, color="r", s=0.5, alpha=0.25)
plt.scatter(ax_mins, x_mins, color="k", s=0.5, alpha=0.25)
plt.xlim(min(a_list), a_max)
plt.ylim(0, 10)
plt.ylabel('$P(t)$', fontsize="x-large")
plt.xlabel('$\\beta_0$', fontsize="x-large")
plt.savefig('MG_bifurcation_a.png')
plt.show()
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# Current tau: 32.0016
# Current tau: 32.0032
# Current tau: 32.0048
# Current tau: 32.0064
# Current tau: 32.008
# Current tau: 32.0096
# Current tau: 32.0112
# Current tau: 32.0128
# Current tau: 32.0144
# Current tau: 32.016
# Current tau: 32.0176
# Current tau: 32.019200000000005
# Current tau: 32.0208
# Current tau: 32.022400000000005
# Current tau: 32.024
# Current tau: 32.025600000000004
# Current tau: 32.0272
# Current tau: 32.028800000000004
# Current tau: 32.0304
# Current tau: 32.032000000000004
# Current tau: 32.0336
# Current tau: 32.0352
# Current tau: 32.0368
# Current tau: 32.0384
# Current tau: 32.04
# Current tau: 32.0416
# Current tau: 32.0432
# Current tau: 32.0448
# Current tau: 32.0464
# Current tau: 32.048
# Current tau: 32.0496
# Current tau: 32.0512
# Current tau: 32.052800000000005
# Current tau: 32.0544
# Current tau: 32.056000000000004
# Current tau: 32.0576
# Current tau: 32.059200000000004
# Current tau: 32.0608
# Current tau: 32.062400000000004
# Current tau: 32.064
# Current tau: 32.0656
# Current tau: 32.0672
# Current tau: 32.0688
# Current tau: 32.0704
# Current tau: 32.072
# Current tau: 32.0736
# Current tau: 32.0752
# Current tau: 32.0768
# Current tau: 32.0784
# Current tau: 32.08
# Current tau: 32.0816
# Current tau: 32.083200000000005
# Current tau: 32.0848
# Current tau: 32.086400000000005
# Current tau: 32.088
# Current tau: 32.089600000000004
# Current tau: 32.0912
# Current tau: 32.092800000000004
# Current tau: 32.0944
# Current tau: 32.096000000000004
# Current tau: 32.0976
# Current tau: 32.0992
# Current tau: 32.1008
# Current tau: 32.1024
# Current tau: 32.104
# Current tau: 32.1056
# Current tau: 32.1072
# Current tau: 32.1088
# Current tau: 32.1104
# Current tau: 32.112
# Current tau: 32.1136
# Current tau: 32.1152
# Current tau: 32.116800000000005
# Current tau: 32.1184
# Current tau: 32.120000000000005
# Current tau: 32.1216
# Current tau: 32.123200000000004
# Current tau: 32.1248
# Current tau: 32.126400000000004
# Current tau: 32.128
# Current tau: 32.1296
# Current tau: 32.1312
# Current tau: 32.1328
# Current tau: 32.1344
# Current tau: 32.136
# Current tau: 32.1376
# Current tau: 32.1392
# Current tau: 32.1408
# Current tau: 32.1424
# Current tau: 32.144
# Current tau: 32.1456
# Current tau: 32.1472
# Current tau: 32.1488
# Current tau: 32.150400000000005
# Current tau: 32.152
# Current tau: 32.153600000000004
# Current tau: 32.1552
# Current tau: 32.156800000000004
# Current tau: 32.1584
# Current tau: 32.160000000000004
# Current tau: 32.1616
# Current tau: 32.1632
# Current tau: 32.1648
# Current tau: 32.1664
# Current tau: 32.168
# Current tau: 32.1696
# Current tau: 32.1712
# Current tau: 32.1728
# Current tau: 32.1744
# Current tau: 32.176
# Current tau: 32.1776
# Current tau: 32.1792
# Current tau: 32.180800000000005
# Current tau: 32.1824
# Current tau: 32.184000000000005
# Current tau: 32.1856
# Current tau: 32.187200000000004
# Current tau: 32.1888
# Current tau: 32.190400000000004
# Current tau: 32.192
# Current tau: 32.1936
# Current tau: 32.1952
# Current tau: 32.1968
# Current tau: 32.1984
# Current tau: 32.2
# Current tau: 32.2016
# Current tau: 32.2032
# Current tau: 32.2048
# Current tau: 32.2064
# Current tau: 32.208
# Current tau: 32.2096
# Current tau: 32.2112
# Current tau: 32.2128
# Current tau: 32.214400000000005
# Current tau: 32.216
# Current tau: 32.217600000000004
# Current tau: 32.2192
# Current tau: 32.220800000000004
# Current tau: 32.2224
# Current tau: 32.224000000000004
# Current tau: 32.2256
# Current tau: 32.2272
# Current tau: 32.2288
# Current tau: 32.2304
# Current tau: 32.232
# Current tau: 32.2336
# Current tau: 32.2352
# Current tau: 32.2368
# Current tau: 32.2384
# Current tau: 32.24
# Current tau: 32.2416
# Current tau: 32.2432
# Current tau: 32.244800000000005
# Current tau: 32.2464
# Current tau: 32.248000000000005
# Current tau: 32.2496
# Current tau: 32.251200000000004
# Current tau: 32.2528
# Current tau: 32.254400000000004
# Current tau: 32.256
# Current tau: 32.257600000000004
# Current tau: 32.2592
# Current tau: 32.2608
# Current tau: 32.2624
# Current tau: 32.264
# Current tau: 32.2656
# Current tau: 32.2672
# Current tau: 32.2688
# Current tau: 32.2704
# Current tau: 32.272
# Current tau: 32.2736
# Current tau: 32.2752
# Current tau: 32.2768
# Current tau: 32.278400000000005
# Current tau: 32.28
# Current tau: 32.281600000000005
# Current tau: 32.2832
# Current tau: 32.284800000000004
# Current tau: 32.2864
# Current tau: 32.288000000000004
# Current tau: 32.2896
# Current tau: 32.2912
# Current tau: 32.2928
# Current tau: 32.2944
# Current tau: 32.296
# Current tau: 32.2976
# Current tau: 32.2992
# Current tau: 32.3008
# Current tau: 32.3024
# Current tau: 32.304
# Current tau: 32.3056
# Current tau: 32.3072
# Current tau: 32.308800000000005
# Current tau: 32.3104
# Current tau: 32.312000000000005
# Current tau: 32.3136
# Current tau: 32.315200000000004
# Current tau: 32.3168
# Current tau: 32.318400000000004
# Current tau: 32.32
# Current tau: 32.321600000000004
# Current tau: 32.3232
# Current tau: 32.3248
# Current tau: 32.3264
# Current tau: 32.328
# Current tau: 32.3296
# Current tau: 32.3312
# Current tau: 32.3328
# Current tau: 32.3344
# Current tau: 32.336
# Current tau: 32.3376
# Current tau: 32.3392
# Current tau: 32.3408
# Current tau: 32.342400000000005
# Current tau: 32.344
# Current tau: 32.345600000000005
# Current tau: 32.3472
# Current tau: 32.348800000000004
# Current tau: 32.3504
# Current tau: 32.352000000000004
# Current tau: 32.3536
# Current tau: 32.3552
# Current tau: 32.3568
# Current tau: 32.3584
# Current tau: 32.36
# Current tau: 32.3616
# Current tau: 32.3632
# Current tau: 32.3648
# Current tau: 32.3664
# Current tau: 32.368
# Current tau: 32.3696
# Current tau: 32.3712
# Current tau: 32.3728
# Current tau: 32.3744
# Current tau: 32.376000000000005
# Current tau: 32.3776
# Current tau: 32.379200000000004
# Current tau: 32.3808
# Current tau: 32.382400000000004
# Current tau: 32.384
# Current tau: 32.385600000000004
# Current tau: 32.3872
# Current tau: 32.3888
# Current tau: 32.3904
# Current tau: 32.392
# Current tau: 32.3936
# Current tau: 32.3952
# Current tau: 32.3968
# Current tau: 32.3984
# Current tau: 32.4
# Current tau: 32.4016
# Current tau: 32.4032
# Current tau: 32.4048
# Current tau: 32.406400000000005
# Current tau: 32.408
# Current tau: 32.409600000000005
# Current tau: 32.4112
# Current tau: 32.412800000000004
# Current tau: 32.4144
# Current tau: 32.416000000000004
# Current tau: 32.4176
# Current tau: 32.419200000000004
# Current tau: 32.4208
# Current tau: 32.4224
# Current tau: 32.424
# Current tau: 32.4256
# Current tau: 32.4272
# Current tau: 32.4288
# Current tau: 32.4304
# Current tau: 32.432
# Current tau: 32.4336
# Current tau: 32.4352
# Current tau: 32.4368
# Current tau: 32.4384
# Current tau: 32.440000000000005
# Current tau: 32.4416
# Current tau: 32.443200000000004
# Current tau: 32.4448
# Current tau: 32.446400000000004
# Current tau: 32.448
# Current tau: 32.449600000000004
# Current tau: 32.4512
# Current tau: 32.4528
# Current tau: 32.4544
# Current tau: 32.456
# Current tau: 32.4576
# Current tau: 32.4592
# Current tau: 32.4608
# Current tau: 32.4624
# Current tau: 32.464
# Current tau: 32.4656
# Current tau: 32.4672
# Current tau: 32.4688
# Current tau: 32.470400000000005
# Current tau: 32.472
# Current tau: 32.473600000000005
# Current tau: 32.4752
# Current tau: 32.476800000000004
# Current tau: 32.4784
# Current tau: 32.480000000000004
# Current tau: 32.4816
# Current tau: 32.483200000000004
# Current tau: 32.4848
# Current tau: 32.4864
# Current tau: 32.488
# Current tau: 32.4896
# Current tau: 32.4912
# Current tau: 32.4928
# Current tau: 32.4944
# Current tau: 32.496
# Current tau: 32.4976
# Current tau: 32.4992
# Current tau: 32.5008
# Current tau: 32.5024
# Current tau: 32.504000000000005
# Current tau: 32.5056
# Current tau: 32.507200000000005
# Current tau: 32.5088
# Current tau: 32.510400000000004
# Current tau: 32.512
# Current tau: 32.513600000000004
# Current tau: 32.5152
# Current tau: 32.5168
# Current tau: 32.5184
# Current tau: 32.52
# Current tau: 32.5216
# Current tau: 32.5232
# Current tau: 32.5248
# Current tau: 32.5264
# Current tau: 32.528
# Current tau: 32.5296
# Current tau: 32.5312
# Current tau: 32.5328
# Current tau: 32.534400000000005
# Current tau: 32.536
# Current tau: 32.537600000000005
# Current tau: 32.5392
# Current tau: 32.540800000000004
# Current tau: 32.5424
# Current tau: 32.544000000000004
# Current tau: 32.5456
# Current tau: 32.547200000000004
# Current tau: 32.5488
# Current tau: 32.5504
# Current tau: 32.552
# Current tau: 32.5536
# Current tau: 32.5552
# Current tau: 32.5568
# Current tau: 32.5584
# Current tau: 32.56
# Current tau: 32.5616
# Current tau: 32.5632
# Current tau: 32.5648
# Current tau: 32.5664
# Current tau: 32.568000000000005
# Current tau: 32.5696
# Current tau: 32.571200000000005
# Current tau: 32.5728
# Current tau: 32.574400000000004
# Current tau: 32.576
# Current tau: 32.577600000000004
# Current tau: 32.5792
# Current tau: 32.5808
# Current tau: 32.5824
# Current tau: 32.584
# Current tau: 32.5856
# Current tau: 32.5872
# Current tau: 32.5888
# Current tau: 32.5904
# Current tau: 32.592
# Current tau: 32.5936
# Current tau: 32.5952
# Current tau: 32.5968
# Current tau: 32.5984
# Current tau: 32.6
# Current tau: 32.601600000000005
# Current tau: 32.6032
# Current tau: 32.604800000000004
# Current tau: 32.6064
# Current tau: 32.608000000000004
# Current tau: 32.6096
# Current tau: 32.611200000000004
# Current tau: 32.6128
# Current tau: 32.6144
# Current tau: 32.616
# Current tau: 32.6176
# Current tau: 32.6192
# Current tau: 32.6208
# Current tau: 32.6224
# Current tau: 32.624
# Current tau: 32.6256
# Current tau: 32.6272
# Current tau: 32.6288
# Current tau: 32.6304
# Current tau: 32.632000000000005
# Current tau: 32.6336
# Current tau: 32.635200000000005
# Current tau: 32.6368
# Current tau: 32.638400000000004
# Current tau: 32.64
# Current tau: 32.641600000000004
# Current tau: 32.6432
# Current tau: 32.644800000000004
# Current tau: 32.6464
# Current tau: 32.648
# Current tau: 32.6496
# Current tau: 32.6512
# Current tau: 32.6528
# Current tau: 32.6544
# Current tau: 32.656
# Current tau: 32.6576
# Current tau: 32.6592
# Current tau: 32.6608
# Current tau: 32.6624
# Current tau: 32.664
# Current tau: 32.665600000000005
# Current tau: 32.6672
# Current tau: 32.668800000000005
# Current tau: 32.6704
# Current tau: 32.672000000000004
# Current tau: 32.6736
# Current tau: 32.675200000000004
# Current tau: 32.6768
# Current tau: 32.6784
# Current tau: 32.68
# Current tau: 32.6816
# Current tau: 32.6832
# Current tau: 32.6848
# Current tau: 32.6864
# Current tau: 32.688
# Current tau: 32.6896
# Current tau: 32.6912
# Current tau: 32.6928
# Current tau: 32.6944
# Current tau: 32.696000000000005
# Current tau: 32.6976
# Current tau: 32.699200000000005
# Current tau: 32.7008
# Current tau: 32.702400000000004
# Current tau: 32.704
# Current tau: 32.705600000000004
# Current tau: 32.7072
# Current tau: 32.708800000000004
# Current tau: 32.7104
# Current tau: 32.712
# Current tau: 32.7136
# Current tau: 32.7152
# Current tau: 32.7168
# Current tau: 32.7184
# Current tau: 32.72
# Current tau: 32.7216
# Current tau: 32.7232
# Current tau: 32.7248
# Current tau: 32.7264
# Current tau: 32.728
# Current tau: 32.729600000000005
# Current tau: 32.7312
# Current tau: 32.732800000000005
# Current tau: 32.7344
# Current tau: 32.736000000000004
# Current tau: 32.7376
# Current tau: 32.739200000000004
# Current tau: 32.7408
# Current tau: 32.7424
# Current tau: 32.744
# Current tau: 32.7456
# Current tau: 32.7472
# Current tau: 32.7488
# Current tau: 32.7504
# Current tau: 32.752
# Current tau: 32.7536
# Current tau: 32.7552
# Current tau: 32.7568
# Current tau: 32.7584
# Current tau: 32.760000000000005
# Current tau: 32.7616
# Current tau: 32.763200000000005
# Current tau: 32.7648
# Current tau: 32.766400000000004
# Current tau: 32.768
# Current tau: 32.769600000000004
# Current tau: 32.7712
# Current tau: 32.772800000000004
# Current tau: 32.7744
# Current tau: 32.776
# Current tau: 32.7776
# Current tau: 32.7792
# Current tau: 32.7808
# Current tau: 32.7824
# Current tau: 32.784
# Current tau: 32.7856
# Current tau: 32.7872
# Current tau: 32.7888
# Current tau: 32.7904
# Current tau: 32.792
# Current tau: 32.793600000000005
# Current tau: 32.7952
# Current tau: 32.796800000000005
# Current tau: 32.7984
# Current tau: 32.800000000000004
# Current tau: 32.8016
# Current tau: 32.803200000000004
# Current tau: 32.8048
# Current tau: 32.806400000000004
# Current tau: 32.808
# Current tau: 32.8096
# Current tau: 32.8112
# Current tau: 32.8128
# Current tau: 32.8144
# Current tau: 32.816
# Current tau: 32.8176
# Current tau: 32.8192
# Current tau: 32.8208
# Current tau: 32.8224
# Current tau: 32.824
# Current tau: 32.8256
# Current tau: 32.827200000000005
# Current tau: 32.8288
# Current tau: 32.830400000000004
# Current tau: 32.832
# Current tau: 32.833600000000004
# Current tau: 32.8352
# Current tau: 32.836800000000004
# Current tau: 32.8384
# Current tau: 32.84
# Current tau: 32.8416
# Current tau: 32.8432
# Current tau: 32.8448
# Current tau: 32.8464
# Current tau: 32.848
# Current tau: 32.8496
# Current tau: 32.8512
# Current tau: 32.8528
# Current tau: 32.8544
# Current tau: 32.856
# Current tau: 32.857600000000005
# Current tau: 32.8592
# Current tau: 32.860800000000005
# Current tau: 32.8624
# Current tau: 32.864000000000004
# Current tau: 32.8656
# Current tau: 32.867200000000004
# Current tau: 32.8688
# Current tau: 32.870400000000004
# Current tau: 32.872
# Current tau: 32.8736
# Current tau: 32.8752
# Current tau: 32.8768
# Current tau: 32.8784
# Current tau: 32.88
# Current tau: 32.8816
# Current tau: 32.8832
# Current tau: 32.8848
# Current tau: 32.8864
# Current tau: 32.888
# Current tau: 32.8896
# Current tau: 32.891200000000005
# Current tau: 32.8928
# Current tau: 32.894400000000005
# Current tau: 32.896
# Current tau: 32.897600000000004
# Current tau: 32.8992
# Current tau: 32.900800000000004
# Current tau: 32.9024
# Current tau: 32.904
# Current tau: 32.9056
# Current tau: 32.9072
# Current tau: 32.9088
# Current tau: 32.9104
# Current tau: 32.912
# Current tau: 32.9136
# Current tau: 32.9152
# Current tau: 32.9168
# Current tau: 32.9184
# Current tau: 32.92
# Current tau: 32.921600000000005
# Current tau: 32.9232
# Current tau: 32.924800000000005
# Current tau: 32.9264
# Current tau: 32.928000000000004
# Current tau: 32.9296
# Current tau: 32.931200000000004
# Current tau: 32.9328
# Current tau: 32.934400000000004
# Current tau: 32.936
# Current tau: 32.9376
# Current tau: 32.9392
# Current tau: 32.9408
# Current tau: 32.9424
# Current tau: 32.944
# Current tau: 32.9456
# Current tau: 32.9472
# Current tau: 32.9488
# Current tau: 32.9504
# Current tau: 32.952
# Current tau: 32.9536
# Current tau: 32.955200000000005
# Current tau: 32.9568
# Current tau: 32.958400000000005
# Current tau: 32.96
# Current tau: 32.961600000000004
# Current tau: 32.9632
# Current tau: 32.964800000000004
# Current tau: 32.9664
# Current tau: 32.968
# Current tau: 32.9696
# Current tau: 32.9712
# Current tau: 32.9728
# Current tau: 32.9744
# Current tau: 32.976
# Current tau: 32.9776
# Current tau: 32.9792
# Current tau: 32.9808
# Current tau: 32.9824
# Current tau: 32.984
# Current tau: 32.9856
# Current tau: 32.9872
# Current tau: 32.988800000000005
# Current tau: 32.9904
# Current tau: 32.992000000000004
# Current tau: 32.9936
# Current tau: 32.995200000000004
# Current tau: 32.9968
# Current tau: 32.998400000000004
# Current tau: 33.0
# Current tau: 33.0016
# Current tau: 33.0032
# Current tau: 33.0048
# Current tau: 33.0064
# Current tau: 33.008
# Current tau: 33.0096
# Current tau: 33.0112
# Current tau: 33.0128
# Current tau: 33.0144
# Current tau: 33.016
# Current tau: 33.0176
# Current tau: 33.019200000000005
# Current tau: 33.0208
# Current tau: 33.022400000000005
# Current tau: 33.024
# Current tau: 33.025600000000004
# Current tau: 33.0272
# Current tau: 33.028800000000004
# Current tau: 33.0304
# Current tau: 33.032000000000004
# Current tau: 33.0336
# Current tau: 33.0352
# Current tau: 33.0368
# Current tau: 33.0384
# Current tau: 33.04
# Current tau: 33.0416
# Current tau: 33.0432
# Current tau: 33.0448
# Current tau: 33.0464
# Current tau: 33.048
# Current tau: 33.0496
# Current tau: 33.0512
# Current tau: 33.052800000000005
# Current tau: 33.0544
# Current tau: 33.056000000000004
# Current tau: 33.0576
# Current tau: 33.059200000000004
# Current tau: 33.0608
# Current tau: 33.062400000000004
# Current tau: 33.064
# Current tau: 33.0656
# Current tau: 33.0672
# Current tau: 33.0688
# Current tau: 33.0704
# Current tau: 33.072
# Current tau: 33.0736
# Current tau: 33.0752
# Current tau: 33.0768
# Current tau: 33.0784
# Current tau: 33.08
# Current tau: 33.0816
# Current tau: 33.083200000000005
# Current tau: 33.0848
# Current tau: 33.086400000000005
# Current tau: 33.088
# Current tau: 33.089600000000004
# Current tau: 33.0912
# Current tau: 33.092800000000004
# Current tau: 33.0944
# Current tau: 33.096000000000004
# Current tau: 33.0976
# Current tau: 33.0992
# Current tau: 33.1008
# Current tau: 33.1024
# Current tau: 33.104
# Current tau: 33.1056
# Current tau: 33.1072
# Current tau: 33.1088
# Current tau: 33.1104
# Current tau: 33.112
# Current tau: 33.1136
# Current tau: 33.1152
# Current tau: 33.116800000000005
# Current tau: 33.1184
# Current tau: 33.120000000000005
# Current tau: 33.1216
# Current tau: 33.123200000000004
# Current tau: 33.1248
# Current tau: 33.126400000000004
# Current tau: 33.128
# Current tau: 33.1296
# Current tau: 33.1312
# Current tau: 33.1328
# Current tau: 33.1344
# Current tau: 33.136
# Current tau: 33.1376
# Current tau: 33.1392
# Current tau: 33.1408
# Current tau: 33.1424
# Current tau: 33.144
# Current tau: 33.1456
# Current tau: 33.147200000000005
# Current tau: 33.1488
# Current tau: 33.150400000000005
# Current tau: 33.152
# Current tau: 33.153600000000004
# Current tau: 33.1552
# Current tau: 33.156800000000004
# Current tau: 33.1584
# Current tau: 33.160000000000004
# Current tau: 33.1616
# Current tau: 33.1632
# Current tau: 33.1648
# Current tau: 33.1664
# Current tau: 33.168
# Current tau: 33.1696
# Current tau: 33.1712
# Current tau: 33.1728
# Current tau: 33.1744
# Current tau: 33.176
# Current tau: 33.1776
# Current tau: 33.1792
# Current tau: 33.180800000000005
# Current tau: 33.1824
# Current tau: 33.184000000000005
# Current tau: 33.1856
# Current tau: 33.187200000000004
# Current tau: 33.1888
# Current tau: 33.190400000000004
# Current tau: 33.192
# Current tau: 33.1936
# Current tau: 33.1952
# Current tau: 33.1968
# Current tau: 33.1984
# Current tau: 33.2
# Current tau: 33.2016
# Current tau: 33.2032
# Current tau: 33.2048
# Current tau: 33.2064
# Current tau: 33.208
# Current tau: 33.2096
# Current tau: 33.2112
# Current tau: 33.2128
# Current tau: 33.214400000000005
# Current tau: 33.216
# Current tau: 33.217600000000004
# Current tau: 33.2192
# Current tau: 33.220800000000004
# Current tau: 33.2224
# Current tau: 33.224000000000004
# Current tau: 33.2256
# Current tau: 33.2272
# Current tau: 33.2288
# Current tau: 33.2304
# Current tau: 33.232
# Current tau: 33.2336
# Current tau: 33.2352
# Current tau: 33.2368
# Current tau: 33.2384
# Current tau: 33.24
# Current tau: 33.2416
# Current tau: 33.2432
# Current tau: 33.244800000000005
# Current tau: 33.2464
# Current tau: 33.248000000000005
# Current tau: 33.2496
# Current tau: 33.251200000000004
# Current tau: 33.2528
# Current tau: 33.254400000000004
# Current tau: 33.256
# Current tau: 33.257600000000004
# Current tau: 33.2592
# Current tau: 33.2608
# Current tau: 33.2624
# Current tau: 33.264
# Current tau: 33.2656
# Current tau: 33.2672
# Current tau: 33.2688
# Current tau: 33.2704
# Current tau: 33.272
# Current tau: 33.2736
# Current tau: 33.2752
# Current tau: 33.2768
# Current tau: 33.278400000000005
# Current tau: 33.28
# Current tau: 33.281600000000005
# Current tau: 33.2832
# Current tau: 33.284800000000004
# Current tau: 33.2864
# Current tau: 33.288000000000004
# Current tau: 33.2896
# Current tau: 33.2912
# Current tau: 33.2928
# Current tau: 33.2944
# Current tau: 33.296
# Current tau: 33.2976
# Current tau: 33.2992
# Current tau: 33.3008
# Current tau: 33.3024
# Current tau: 33.304
# Current tau: 33.3056
# Current tau: 33.3072
# Current tau: 33.308800000000005
# Current tau: 33.3104
# Current tau: 33.312000000000005
# Current tau: 33.3136
# Current tau: 33.315200000000004
# Current tau: 33.3168
# Current tau: 33.318400000000004
# Current tau: 33.32
# Current tau: 33.321600000000004
# Current tau: 33.3232
# Current tau: 33.3248
# Current tau: 33.3264
# Current tau: 33.328
# Current tau: 33.3296
# Current tau: 33.3312
# Current tau: 33.3328
# Current tau: 33.3344
# Current tau: 33.336
# Current tau: 33.3376
# Current tau: 33.3392
# Current tau: 33.3408
# Current tau: 33.342400000000005
# Current tau: 33.344
# Current tau: 33.345600000000005
# Current tau: 33.3472
# Current tau: 33.348800000000004
# Current tau: 33.3504
# Current tau: 33.352000000000004
# Current tau: 33.3536
# Current tau: 33.3552
# Current tau: 33.3568
# Current tau: 33.3584
# Current tau: 33.36
# Current tau: 33.3616
# Current tau: 33.3632
# Current tau: 33.3648
# Current tau: 33.3664
# Current tau: 33.368
# Current tau: 33.3696
# Current tau: 33.3712
# Current tau: 33.372800000000005
# Current tau: 33.3744
# Current tau: 33.376000000000005
# Current tau: 33.3776
# Current tau: 33.379200000000004
# Current tau: 33.3808
# Current tau: 33.382400000000004
# Current tau: 33.384
# Current tau: 33.385600000000004
# Current tau: 33.3872
# Current tau: 33.3888
# Current tau: 33.3904
# Current tau: 33.392
# Current tau: 33.3936
# Current tau: 33.3952
# Current tau: 33.3968
# Current tau: 33.3984
# Current tau: 33.4
# Current tau: 33.4016
# Current tau: 33.4032
# Current tau: 33.4048
# Current tau: 33.406400000000005
# Current tau: 33.408
# Current tau: 33.409600000000005
# Current tau: 33.4112
# Current tau: 33.412800000000004
# Current tau: 33.4144
# Current tau: 33.416000000000004
# Current tau: 33.4176
# Current tau: 33.419200000000004
# Current tau: 33.4208
# Current tau: 33.4224
# Current tau: 33.424
# Current tau: 33.4256
# Current tau: 33.4272
# Current tau: 33.4288
# Current tau: 33.4304
# Current tau: 33.432
# Current tau: 33.4336
# Current tau: 33.4352
# Current tau: 33.4368
# Current tau: 33.4384
# Current tau: 33.440000000000005
# Current tau: 33.4416
# Current tau: 33.443200000000004
# Current tau: 33.4448
# Current tau: 33.446400000000004
# Current tau: 33.448
# Current tau: 33.449600000000004
# Current tau: 33.4512
# Current tau: 33.4528
# Current tau: 33.4544
# Current tau: 33.456
# Current tau: 33.4576
# Current tau: 33.4592
# Current tau: 33.4608
# Current tau: 33.4624
# Current tau: 33.464
# Current tau: 33.4656
# Current tau: 33.4672
# Current tau: 33.4688
# Current tau: 33.470400000000005
# Current tau: 33.472
# Current tau: 33.473600000000005
# Current tau: 33.4752
# Current tau: 33.476800000000004
# Current tau: 33.4784
# Current tau: 33.480000000000004
# Current tau: 33.4816
# Current tau: 33.483200000000004
# Current tau: 33.4848
# Current tau: 33.4864
# Current tau: 33.488
# Current tau: 33.4896
# Current tau: 33.4912
# Current tau: 33.4928
# Current tau: 33.4944
# Current tau: 33.496
# Current tau: 33.4976
# Current tau: 33.4992
# Current tau: 33.5008
# Current tau: 33.5024
# Current tau: 33.504000000000005
# Current tau: 33.5056
# Current tau: 33.507200000000005
# Current tau: 33.5088
# Current tau: 33.510400000000004
# Current tau: 33.512
# Current tau: 33.513600000000004
# Current tau: 33.5152
# Current tau: 33.5168
# Current tau: 33.5184
# Current tau: 33.52
# Current tau: 33.5216
# Current tau: 33.5232
# Current tau: 33.5248
# Current tau: 33.5264
# Current tau: 33.528
# Current tau: 33.5296
# Current tau: 33.5312
# Current tau: 33.5328
# Current tau: 33.534400000000005
# Current tau: 33.536
# Current tau: 33.537600000000005
# Current tau: 33.5392
# Current tau: 33.540800000000004
# Current tau: 33.5424
# Current tau: 33.544000000000004
# Current tau: 33.5456
# Current tau: 33.547200000000004
# Current tau: 33.5488
# Current tau: 33.5504
# Current tau: 33.552
# Current tau: 33.5536
# Current tau: 33.5552
# Current tau: 33.5568
# Current tau: 33.5584
# Current tau: 33.56
# Current tau: 33.5616
# Current tau: 33.5632
# Current tau: 33.5648
# Current tau: 33.5664
# Current tau: 33.568000000000005
# Current tau: 33.5696
# Current tau: 33.571200000000005
# Current tau: 33.5728
# Current tau: 33.574400000000004
# Current tau: 33.576
# Current tau: 33.577600000000004
# Current tau: 33.5792
# Current tau: 33.5808
# Current tau: 33.5824
# Current tau: 33.584
# Current tau: 33.5856
# Current tau: 33.5872
# Current tau: 33.5888
# Current tau: 33.5904
# Current tau: 33.592
# Current tau: 33.5936
# Current tau: 33.5952
# Current tau: 33.5968
# Current tau: 33.598400000000005
# Current tau: 33.6
# Current tau: 33.601600000000005
# Current tau: 33.6032
# Current tau: 33.604800000000004
# Current tau: 33.6064
# Current tau: 33.608000000000004
# Current tau: 33.6096
# Current tau: 33.611200000000004
# Current tau: 33.6128
# Current tau: 33.6144
# Current tau: 33.616
# Current tau: 33.6176
# Current tau: 33.6192
# Current tau: 33.6208
# Current tau: 33.6224
# Current tau: 33.624
# Current tau: 33.6256
# Current tau: 33.6272
# Current tau: 33.6288
# Current tau: 33.6304
# Current tau: 33.632000000000005
# Current tau: 33.6336
# Current tau: 33.635200000000005
# Current tau: 33.6368
# Current tau: 33.638400000000004
# Current tau: 33.64
# Current tau: 33.641600000000004
# Current tau: 33.6432
# Current tau: 33.644800000000004
# Current tau: 33.6464
# Current tau: 33.648
# Current tau: 33.6496
# Current tau: 33.6512
# Current tau: 33.6528
# Current tau: 33.6544
# Current tau: 33.656
# Current tau: 33.6576
# Current tau: 33.6592
# Current tau: 33.6608
# Current tau: 33.6624
# Current tau: 33.664
# Current tau: 33.665600000000005
# Current tau: 33.6672
# Current tau: 33.668800000000005
# Current tau: 33.6704
# Current tau: 33.672000000000004
# Current tau: 33.6736
# Current tau: 33.675200000000004
# Current tau: 33.6768
# Current tau: 33.6784
# Current tau: 33.68
# Current tau: 33.6816
# Current tau: 33.6832
# Current tau: 33.6848
# Current tau: 33.6864
# Current tau: 33.688
# Current tau: 33.6896
# Current tau: 33.6912
# Current tau: 33.6928
# Current tau: 33.6944
# Current tau: 33.696000000000005
# Current tau: 33.6976
# Current tau: 33.699200000000005
# Current tau: 33.7008
# Current tau: 33.702400000000004
# Current tau: 33.704
# Current tau: 33.705600000000004
# Current tau: 33.7072
# Current tau: 33.708800000000004
# Current tau: 33.7104
# Current tau: 33.712
# Current tau: 33.7136
# Current tau: 33.7152
# Current tau: 33.7168
# Current tau: 33.7184
# Current tau: 33.72
# Current tau: 33.7216
# Current tau: 33.7232
# Current tau: 33.7248
# Current tau: 33.7264
# Current tau: 33.728
# Current tau: 33.729600000000005
# Current tau: 33.7312
# Current tau: 33.732800000000005
# Current tau: 33.7344
# Current tau: 33.736000000000004
# Current tau: 33.7376
# Current tau: 33.739200000000004
# Current tau: 33.7408
# Current tau: 33.7424
# Current tau: 33.744
# Current tau: 33.7456
# Current tau: 33.7472
# Current tau: 33.7488
# Current tau: 33.7504
# Current tau: 33.752
# Current tau: 33.7536
# Current tau: 33.7552
# Current tau: 33.7568
# Current tau: 33.7584
# Current tau: 33.760000000000005
# Current tau: 33.7616
# Current tau: 33.763200000000005
# Current tau: 33.7648
# Current tau: 33.766400000000004
# Current tau: 33.768
# Current tau: 33.769600000000004
# Current tau: 33.7712
# Current tau: 33.772800000000004
# Current tau: 33.7744
# Current tau: 33.776
# Current tau: 33.7776
# Current tau: 33.7792
# Current tau: 33.7808
# Current tau: 33.7824
# Current tau: 33.784
# Current tau: 33.7856
# Current tau: 33.7872
# Current tau: 33.7888
# Current tau: 33.7904
# Current tau: 33.792
# Current tau: 33.793600000000005
# Current tau: 33.7952
# Current tau: 33.796800000000005
# Current tau: 33.7984
# Current tau: 33.800000000000004
# Current tau: 33.8016
# Current tau: 33.803200000000004
# Current tau: 33.8048
# Current tau: 33.806400000000004
# Current tau: 33.808
# Current tau: 33.8096
# Current tau: 33.8112
# Current tau: 33.8128
# Current tau: 33.8144
# Current tau: 33.816
# Current tau: 33.8176
# Current tau: 33.8192
# Current tau: 33.8208
# Current tau: 33.8224
# Current tau: 33.824000000000005
# Current tau: 33.8256
# Current tau: 33.827200000000005
# Current tau: 33.8288
# Current tau: 33.830400000000004
# Current tau: 33.832
# Current tau: 33.833600000000004
# Current tau: 33.8352
# Current tau: 33.836800000000004
# Current tau: 33.8384
# Current tau: 33.84
# Current tau: 33.8416
# Current tau: 33.8432
# Current tau: 33.8448
# Current tau: 33.8464
# Current tau: 33.848
# Current tau: 33.8496
# Current tau: 33.8512
# Current tau: 33.8528
# Current tau: 33.8544
# Current tau: 33.856
# Current tau: 33.857600000000005
# Current tau: 33.8592
# Current tau: 33.860800000000005
# Current tau: 33.8624
# Current tau: 33.864000000000004
# Current tau: 33.8656
# Current tau: 33.867200000000004
# Current tau: 33.8688
# Current tau: 33.870400000000004
# Current tau: 33.872
# Current tau: 33.8736
# Current tau: 33.8752
# Current tau: 33.8768
# Current tau: 33.8784
# Current tau: 33.88
# Current tau: 33.8816
# Current tau: 33.8832
# Current tau: 33.8848
# Current tau: 33.8864
# Current tau: 33.888
# Current tau: 33.8896
# Current tau: 33.891200000000005
# Current tau: 33.8928
# Current tau: 33.894400000000005
# Current tau: 33.896
# Current tau: 33.897600000000004
# Current tau: 33.8992
# Current tau: 33.900800000000004
# Current tau: 33.9024
# Current tau: 33.904
# Current tau: 33.9056
# Current tau: 33.9072
# Current tau: 33.9088
# Current tau: 33.9104
# Current tau: 33.912
# Current tau: 33.9136
# Current tau: 33.9152
# Current tau: 33.9168
# Current tau: 33.9184
# Current tau: 33.92
# Current tau: 33.921600000000005
# Current tau: 33.9232
# Current tau: 33.924800000000005
# Current tau: 33.9264
# Current tau: 33.928000000000004
# Current tau: 33.9296
# Current tau: 33.931200000000004
# Current tau: 33.9328
# Current tau: 33.934400000000004
# Current tau: 33.936
# Current tau: 33.9376
# Current tau: 33.9392
# Current tau: 33.9408
# Current tau: 33.9424
# Current tau: 33.944
# Current tau: 33.9456
# Current tau: 33.9472
# Current tau: 33.9488
# Current tau: 33.9504
# Current tau: 33.952
# Current tau: 33.9536
# Current tau: 33.955200000000005
# Current tau: 33.9568
# Current tau: 33.958400000000005
# Current tau: 33.96
# Current tau: 33.961600000000004
# Current tau: 33.9632
# Current tau: 33.964800000000004
# Current tau: 33.9664
# Current tau: 33.968
# Current tau: 33.9696
# Current tau: 33.9712
# Current tau: 33.9728
# Current tau: 33.9744
# Current tau: 33.976
# Current tau: 33.9776
# Current tau: 33.9792
# Current tau: 33.9808
# Current tau: 33.9824
# Current tau: 33.984
# Current tau: 33.985600000000005
# Current tau: 33.9872
# Current tau: 33.988800000000005
# Current tau: 33.9904
# Current tau: 33.992000000000004
# Current tau: 33.9936
# Current tau: 33.995200000000004
# Current tau: 33.9968
# Current tau: 33.998400000000004
# Current tau: 34.0
# Current tau: 34.0016
# Current tau: 34.0032
# Current tau: 34.0048
# Current tau: 34.0064
# Current tau: 34.008
# Current tau: 34.0096
# Current tau: 34.0112
# Current tau: 34.0128
# Current tau: 34.0144
# Current tau: 34.016
# Current tau: 34.0176
# Current tau: 34.019200000000005
# Current tau: 34.0208
# Current tau: 34.022400000000005
# Current tau: 34.024
# Current tau: 34.025600000000004
# Current tau: 34.0272
# Current tau: 34.028800000000004
# Current tau: 34.0304
# Current tau: 34.032000000000004
# Current tau: 34.0336
# Current tau: 34.0352
# Current tau: 34.0368
# Current tau: 34.0384
# Current tau: 34.04
# Current tau: 34.0416
# Current tau: 34.0432
# Current tau: 34.0448
# Current tau: 34.0464
# Current tau: 34.048
# Current tau: 34.0496
# Current tau: 34.0512
# Current tau: 34.052800000000005
# Current tau: 34.0544
# Current tau: 34.056000000000004
# Current tau: 34.0576
# Current tau: 34.059200000000004
# Current tau: 34.0608
# Current tau: 34.062400000000004
# Current tau: 34.064
# Current tau: 34.0656
# Current tau: 34.0672
# Current tau: 34.0688
# Current tau: 34.0704
# Current tau: 34.072
# Current tau: 34.0736
# Current tau: 34.0752
# Current tau: 34.0768
# Current tau: 34.0784
# Current tau: 34.08
# Current tau: 34.0816
# Current tau: 34.083200000000005
# Current tau: 34.0848
# Current tau: 34.086400000000005
# Current tau: 34.088
# Current tau: 34.089600000000004
# Current tau: 34.0912
# Current tau: 34.092800000000004
# Current tau: 34.0944
# Current tau: 34.096000000000004
# Current tau: 34.0976
# Current tau: 34.0992
# Current tau: 34.1008
# Current tau: 34.1024
# Current tau: 34.104
# Current tau: 34.1056
# Current tau: 34.1072
# Current tau: 34.1088
# Current tau: 34.1104
# Current tau: 34.112
# Current tau: 34.1136
# Current tau: 34.1152
# Current tau: 34.116800000000005
# Current tau: 34.1184
# Current tau: 34.120000000000005
# Current tau: 34.1216
# Current tau: 34.123200000000004
# Current tau: 34.1248
# Current tau: 34.126400000000004
# Current tau: 34.128
# Current tau: 34.1296
# Current tau: 34.1312
# Current tau: 34.1328
# Current tau: 34.1344
# Current tau: 34.136
# Current tau: 34.1376
# Current tau: 34.1392
# Current tau: 34.1408
# Current tau: 34.1424
# Current tau: 34.144
# Current tau: 34.1456
# Current tau: 34.147200000000005
# Current tau: 34.1488
# Current tau: 34.150400000000005
# Current tau: 34.152
# Current tau: 34.153600000000004
# Current tau: 34.1552
# Current tau: 34.156800000000004
# Current tau: 34.1584
# Current tau: 34.160000000000004
# Current tau: 34.1616
# Current tau: 34.1632
# Current tau: 34.1648
# Current tau: 34.1664
# Current tau: 34.168
# Current tau: 34.1696
# Current tau: 34.1712
# Current tau: 34.1728
# Current tau: 34.1744
# Current tau: 34.176
# Current tau: 34.1776
# Current tau: 34.1792
# Current tau: 34.180800000000005
# Current tau: 34.1824
# Current tau: 34.184000000000005
# Current tau: 34.1856
# Current tau: 34.187200000000004
# Current tau: 34.1888
# Current tau: 34.190400000000004
# Current tau: 34.192
# Current tau: 34.1936
# Current tau: 34.1952
# Current tau: 34.1968
# Current tau: 34.1984
# Current tau: 34.2
# Current tau: 34.2016
# Current tau: 34.2032
# Current tau: 34.2048
# Current tau: 34.2064
# Current tau: 34.208
# Current tau: 34.2096
# Current tau: 34.211200000000005
# Current tau: 34.2128
# Current tau: 34.214400000000005
# Current tau: 34.216
# Current tau: 34.217600000000004
# Current tau: 34.2192
# Current tau: 34.220800000000004
# Current tau: 34.2224
# Current tau: 34.224000000000004
# Current tau: 34.2256
# Current tau: 34.2272
# Current tau: 34.2288
# Current tau: 34.2304
# Current tau: 34.232
# Current tau: 34.2336
# Current tau: 34.2352
# Current tau: 34.2368
# Current tau: 34.2384
# Current tau: 34.24
# Current tau: 34.2416
# Current tau: 34.2432
# Current tau: 34.244800000000005
# Current tau: 34.2464
# Current tau: 34.248000000000005
# Current tau: 34.2496
# Current tau: 34.251200000000004
# Current tau: 34.2528
# Current tau: 34.254400000000004
# Current tau: 34.256
# Current tau: 34.257600000000004
# Current tau: 34.2592
# Current tau: 34.2608
# Current tau: 34.2624
# Current tau: 34.264
# Current tau: 34.2656
# Current tau: 34.2672
# Current tau: 34.2688
# Current tau: 34.2704
# Current tau: 34.272
# Current tau: 34.2736
# Current tau: 34.2752
# Current tau: 34.2768
# Current tau: 34.278400000000005
# Current tau: 34.28
# Current tau: 34.281600000000005
# Current tau: 34.2832
# Current tau: 34.284800000000004
# Current tau: 34.2864
# Current tau: 34.288000000000004
# Current tau: 34.2896
# Current tau: 34.2912
# Current tau: 34.2928
# Current tau: 34.2944
# Current tau: 34.296
# Current tau: 34.2976
# Current tau: 34.2992
# Current tau: 34.3008
# Current tau: 34.3024
# Current tau: 34.304
# Current tau: 34.3056
# Current tau: 34.3072
# Current tau: 34.308800000000005
# Current tau: 34.3104
# Current tau: 34.312000000000005
# Current tau: 34.3136
# Current tau: 34.315200000000004
# Current tau: 34.3168
# Current tau: 34.318400000000004
# Current tau: 34.32
# Current tau: 34.321600000000004
# Current tau: 34.3232
# Current tau: 34.3248
# Current tau: 34.3264
# Current tau: 34.328
# Current tau: 34.3296
# Current tau: 34.3312
# Current tau: 34.3328
# Current tau: 34.3344
# Current tau: 34.336
# Current tau: 34.3376
# Current tau: 34.3392
# Current tau: 34.3408
# Current tau: 34.342400000000005
# Current tau: 34.344
# Current tau: 34.345600000000005
# Current tau: 34.3472
# Current tau: 34.348800000000004
# Current tau: 34.3504
# Current tau: 34.352000000000004
# Current tau: 34.3536
# Current tau: 34.3552
# Current tau: 34.3568
# Current tau: 34.3584
# Current tau: 34.36
# Current tau: 34.3616
# Current tau: 34.3632
# Current tau: 34.3648
# Current tau: 34.3664
# Current tau: 34.368
# Current tau: 34.3696
# Current tau: 34.3712
# Current tau: 34.372800000000005
# Current tau: 34.3744
# Current tau: 34.376000000000005
# Current tau: 34.3776
# Current tau: 34.379200000000004
# Current tau: 34.3808
# Current tau: 34.382400000000004
# Current tau: 34.384
# Current tau: 34.385600000000004
# Current tau: 34.3872
# Current tau: 34.3888
# Current tau: 34.3904
# Current tau: 34.392
# Current tau: 34.3936
# Current tau: 34.3952
# Current tau: 34.3968
# Current tau: 34.3984
# Current tau: 34.4
# Current tau: 34.4016
# Current tau: 34.4032
# Current tau: 34.4048
# Current tau: 34.406400000000005
# Current tau: 34.408
# Current tau: 34.409600000000005
# Current tau: 34.4112
# Current tau: 34.412800000000004
# Current tau: 34.4144
# Current tau: 34.416000000000004
# Current tau: 34.4176
# Current tau: 34.419200000000004
# Current tau: 34.4208
# Current tau: 34.4224
# Current tau: 34.424
# Current tau: 34.4256
# Current tau: 34.4272
# Current tau: 34.4288
# Current tau: 34.4304
# Current tau: 34.432
# Current tau: 34.4336
# Current tau: 34.4352
# Current tau: 34.436800000000005
# Current tau: 34.4384
# Current tau: 34.440000000000005
# Current tau: 34.4416
# Current tau: 34.443200000000004
# Current tau: 34.4448
# Current tau: 34.446400000000004
# Current tau: 34.448
# Current tau: 34.449600000000004
# Current tau: 34.4512
# Current tau: 34.4528
# Current tau: 34.4544
# Current tau: 34.456
# Current tau: 34.4576
# Current tau: 34.4592
# Current tau: 34.4608
# Current tau: 34.4624
# Current tau: 34.464
# Current tau: 34.4656
# Current tau: 34.4672
# Current tau: 34.4688
# Current tau: 34.470400000000005
# Current tau: 34.472
# Current tau: 34.473600000000005
# Current tau: 34.4752
# Current tau: 34.476800000000004
# Current tau: 34.4784
# Current tau: 34.480000000000004
# Current tau: 34.4816
# Current tau: 34.483200000000004
# Current tau: 34.4848
# Current tau: 34.4864
# Current tau: 34.488
# Current tau: 34.4896
# Current tau: 34.4912
# Current tau: 34.4928
# Current tau: 34.4944
# Current tau: 34.496
# Current tau: 34.4976
# Current tau: 34.4992
# Current tau: 34.5008
# Current tau: 34.5024
# Current tau: 34.504000000000005
# Current tau: 34.5056
# Current tau: 34.507200000000005
# Current tau: 34.5088
# Current tau: 34.510400000000004
# Current tau: 34.512
# Current tau: 34.513600000000004
# Current tau: 34.5152
# Current tau: 34.5168
# Current tau: 34.5184
# Current tau: 34.52
# Current tau: 34.5216
# Current tau: 34.5232
# Current tau: 34.5248
# Current tau: 34.5264
# Current tau: 34.528
# Current tau: 34.5296
# Current tau: 34.5312
# Current tau: 34.5328
# Current tau: 34.534400000000005
# Current tau: 34.536
# Current tau: 34.537600000000005
# Current tau: 34.5392
# Current tau: 34.540800000000004
# Current tau: 34.5424
# Current tau: 34.544000000000004
# Current tau: 34.5456
# Current tau: 34.547200000000004
# Current tau: 34.5488
# Current tau: 34.5504
# Current tau: 34.552
# Current tau: 34.5536
# Current tau: 34.5552
# Current tau: 34.5568
# Current tau: 34.5584
# Current tau: 34.56
# Current tau: 34.5616
# Current tau: 34.5632
# Current tau: 34.5648
# Current tau: 34.5664
# Current tau: 34.568000000000005
# Current tau: 34.5696
# Current tau: 34.571200000000005
# Current tau: 34.5728
# Current tau: 34.574400000000004
# Current tau: 34.576
# Current tau: 34.577600000000004
# Current tau: 34.5792
# Current tau: 34.5808
# Current tau: 34.5824
# Current tau: 34.584
# Current tau: 34.5856
# Current tau: 34.5872
# Current tau: 34.5888
# Current tau: 34.5904
# Current tau: 34.592
# Current tau: 34.5936
# Current tau: 34.5952
# Current tau: 34.5968
# Current tau: 34.598400000000005
# Current tau: 34.6
# Current tau: 34.601600000000005
# Current tau: 34.6032
# Current tau: 34.604800000000004
# Current tau: 34.6064
# Current tau: 34.608000000000004
# Current tau: 34.6096
# Current tau: 34.611200000000004
# Current tau: 34.6128
# Current tau: 34.6144
# Current tau: 34.616
# Current tau: 34.6176
# Current tau: 34.6192
# Current tau: 34.6208
# Current tau: 34.6224
# Current tau: 34.624
# Current tau: 34.6256
# Current tau: 34.6272
# Current tau: 34.6288
# Current tau: 34.6304
# Current tau: 34.632000000000005
# Current tau: 34.6336
# Current tau: 34.635200000000005
# Current tau: 34.6368
# Current tau: 34.638400000000004
# Current tau: 34.64
# Current tau: 34.641600000000004
# Current tau: 34.6432
# Current tau: 34.644800000000004
# Current tau: 34.6464
# Current tau: 34.648
# Current tau: 34.6496
# Current tau: 34.6512
# Current tau: 34.6528
# Current tau: 34.6544
# Current tau: 34.656
# Current tau: 34.6576
# Current tau: 34.6592
# Current tau: 34.6608
# Current tau: 34.662400000000005
# Current tau: 34.664
# Current tau: 34.665600000000005
# Current tau: 34.6672
# Current tau: 34.668800000000005
# Current tau: 34.6704
# Current tau: 34.672000000000004
# Current tau: 34.6736
# Current tau: 34.675200000000004
# Current tau: 34.6768
# Current tau: 34.6784
# Current tau: 34.68
# Current tau: 34.6816
# Current tau: 34.6832
# Current tau: 34.6848
# Current tau: 34.6864
# Current tau: 34.688
# Current tau: 34.6896
# Current tau: 34.6912
# Current tau: 34.6928
# Current tau: 34.6944
# Current tau: 34.696000000000005
# Current tau: 34.6976
# Current tau: 34.699200000000005
# Current tau: 34.7008
# Current tau: 34.702400000000004
# Current tau: 34.704
# Current tau: 34.705600000000004
# Current tau: 34.7072
# Current tau: 34.708800000000004
# Current tau: 34.7104
# Current tau: 34.712
# Current tau: 34.7136
# Current tau: 34.7152
# Current tau: 34.7168
# Current tau: 34.7184
# Current tau: 34.72
# Current tau: 34.7216
# Current tau: 34.7232
# Current tau: 34.7248
# Current tau: 34.7264
# Current tau: 34.728
# Current tau: 34.729600000000005
# Current tau: 34.7312
# Current tau: 34.732800000000005
# Current tau: 34.7344
# Current tau: 34.736000000000004
# Current tau: 34.7376
# Current tau: 34.739200000000004
# Current tau: 34.7408
# Current tau: 34.7424
# Current tau: 34.744
# Current tau: 34.7456
# Current tau: 34.7472
# Current tau: 34.7488
# Current tau: 34.7504
# Current tau: 34.752
# Current tau: 34.7536
# Current tau: 34.7552
# Current tau: 34.7568
# Current tau: 34.7584
# Current tau: 34.760000000000005
# Current tau: 34.7616
# Current tau: 34.763200000000005
# Current tau: 34.7648
# Current tau: 34.766400000000004
# Current tau: 34.768
# Current tau: 34.769600000000004
# Current tau: 34.7712
# Current tau: 34.772800000000004
# Current tau: 34.7744
# Current tau: 34.776
# Current tau: 34.7776
# Current tau: 34.7792
# Current tau: 34.7808
# Current tau: 34.7824
# Current tau: 34.784
# Current tau: 34.7856
# Current tau: 34.7872
# Current tau: 34.7888
# Current tau: 34.7904
# Current tau: 34.792
# Current tau: 34.793600000000005
# Current tau: 34.7952
# Current tau: 34.796800000000005
# Current tau: 34.7984
# Current tau: 34.800000000000004
# Current tau: 34.8016
# Current tau: 34.803200000000004
# Current tau: 34.8048
# Current tau: 34.806400000000004
# Current tau: 34.808
# Current tau: 34.8096
# Current tau: 34.8112
# Current tau: 34.8128
# Current tau: 34.8144
# Current tau: 34.816
# Current tau: 34.8176
# Current tau: 34.8192
# Current tau: 34.8208
# Current tau: 34.8224
# Current tau: 34.824000000000005
# Current tau: 34.8256
# Current tau: 34.827200000000005
# Current tau: 34.8288
# Current tau: 34.830400000000004
# Current tau: 34.832
# Current tau: 34.833600000000004
# Current tau: 34.8352
# Current tau: 34.836800000000004
# Current tau: 34.8384
# Current tau: 34.84
# Current tau: 34.8416
# Current tau: 34.8432
# Current tau: 34.8448
# Current tau: 34.8464
# Current tau: 34.848
# Current tau: 34.8496
# Current tau: 34.8512
# Current tau: 34.8528
# Current tau: 34.8544
# Current tau: 34.856
# Current tau: 34.857600000000005
# Current tau: 34.8592
# Current tau: 34.860800000000005
# Current tau: 34.8624
# Current tau: 34.864000000000004
# Current tau: 34.8656
# Current tau: 34.867200000000004
# Current tau: 34.8688
# Current tau: 34.870400000000004
# Current tau: 34.872
# Current tau: 34.8736
# Current tau: 34.8752
# Current tau: 34.8768
# Current tau: 34.8784
# Current tau: 34.88
# Current tau: 34.8816
# Current tau: 34.8832
# Current tau: 34.8848
# Current tau: 34.8864
# Current tau: 34.888
# Current tau: 34.8896
# Current tau: 34.891200000000005
# Current tau: 34.8928
# Current tau: 34.894400000000005
# Current tau: 34.896
# Current tau: 34.897600000000004
# Current tau: 34.8992
# Current tau: 34.900800000000004
# Current tau: 34.9024
# Current tau: 34.904
# Current tau: 34.9056
# Current tau: 34.9072
# Current tau: 34.9088
# Current tau: 34.9104
# Current tau: 34.912
# Current tau: 34.9136
# Current tau: 34.9152
# Current tau: 34.9168
# Current tau: 34.9184
# Current tau: 34.92
# Current tau: 34.921600000000005
# Current tau: 34.9232
# Current tau: 34.924800000000005
# Current tau: 34.9264
# Current tau: 34.928000000000004
# Current tau: 34.9296
# Current tau: 34.931200000000004
# Current tau: 34.9328
# Current tau: 34.934400000000004
# Current tau: 34.936
# Current tau: 34.9376
# Current tau: 34.9392
# Current tau: 34.9408
# Current tau: 34.9424
# Current tau: 34.944
# Current tau: 34.9456
# Current tau: 34.9472
# Current tau: 34.9488
# Current tau: 34.9504
# Current tau: 34.952
# Current tau: 34.9536
# Current tau: 34.955200000000005
# Current tau: 34.9568
# Current tau: 34.958400000000005
# Current tau: 34.96
# Current tau: 34.961600000000004
# Current tau: 34.9632
# Current tau: 34.964800000000004
# Current tau: 34.9664
# Current tau: 34.968
# Current tau: 34.9696
# Current tau: 34.9712
# Current tau: 34.9728
# Current tau: 34.9744
# Current tau: 34.976
# Current tau: 34.9776
# Current tau: 34.9792
# Current tau: 34.9808
# Current tau: 34.9824
# Current tau: 34.984
# Current tau: 34.985600000000005
# Current tau: 34.9872
# Current tau: 34.988800000000005
# Current tau: 34.9904
# Current tau: 34.992000000000004
# Current tau: 34.9936
# Current tau: 34.995200000000004
# Current tau: 34.9968
# Current tau: 34.998400000000004
# Current tau: 35.0
# Current tau: 35.0016
# Current tau: 35.0032
# Current tau: 35.0048
# Current tau: 35.0064
# Current tau: 35.008
# Current tau: 35.0096
# Current tau: 35.0112
# Current tau: 35.0128
# Current tau: 35.0144
# Current tau: 35.016
# Current tau: 35.0176
# Current tau: 35.019200000000005
# Current tau: 35.0208
# Current tau: 35.022400000000005
# Current tau: 35.024
# Current tau: 35.025600000000004
# Current tau: 35.0272
# Current tau: 35.028800000000004
# Current tau: 35.0304
# Current tau: 35.032000000000004
# Current tau: 35.0336
# Current tau: 35.0352
# Current tau: 35.0368
# Current tau: 35.0384
# Current tau: 35.04
# Current tau: 35.0416
# Current tau: 35.0432
# Current tau: 35.0448
# Current tau: 35.0464
# Current tau: 35.048
# Current tau: 35.049600000000005
# Current tau: 35.0512
# Current tau: 35.052800000000005
# Current tau: 35.0544
# Current tau: 35.056000000000004
# Current tau: 35.0576
# Current tau: 35.059200000000004
# Current tau: 35.0608
# Current tau: 35.062400000000004
# Current tau: 35.064
# Current tau: 35.0656
# Current tau: 35.0672
# Current tau: 35.0688
# Current tau: 35.0704
# Current tau: 35.072
# Current tau: 35.0736
# Current tau: 35.0752
# Current tau: 35.0768
# Current tau: 35.0784
# Current tau: 35.08
# Current tau: 35.0816
# Current tau: 35.083200000000005
# Current tau: 35.0848
# Current tau: 35.086400000000005
# Current tau: 35.088
# Current tau: 35.089600000000004
# Current tau: 35.0912
# Current tau: 35.092800000000004
# Current tau: 35.0944
# Current tau: 35.096000000000004
# Current tau: 35.0976
# Current tau: 35.0992
# Current tau: 35.1008
# Current tau: 35.1024
# Current tau: 35.104
# Current tau: 35.1056
# Current tau: 35.1072
# Current tau: 35.1088
# Current tau: 35.1104
# Current tau: 35.112
# Current tau: 35.1136
# Current tau: 35.1152
# Current tau: 35.116800000000005
# Current tau: 35.1184
# Current tau: 35.120000000000005
# Current tau: 35.1216
# Current tau: 35.123200000000004
# Current tau: 35.1248
# Current tau: 35.126400000000004
# Current tau: 35.128
# Current tau: 35.1296
# Current tau: 35.1312
# Current tau: 35.1328
# Current tau: 35.1344
# Current tau: 35.136
# Current tau: 35.1376
# Current tau: 35.1392
# Current tau: 35.1408
# Current tau: 35.1424
# Current tau: 35.144
# Current tau: 35.1456
# Current tau: 35.147200000000005
# Current tau: 35.1488
# Current tau: 35.150400000000005
# Current tau: 35.152
# Current tau: 35.153600000000004
# Current tau: 35.1552
# Current tau: 35.156800000000004
# Current tau: 35.1584
# Current tau: 35.160000000000004
# Current tau: 35.1616
# Current tau: 35.1632
# Current tau: 35.1648
# Current tau: 35.1664
# Current tau: 35.168
# Current tau: 35.1696
# Current tau: 35.1712
# Current tau: 35.1728
# Current tau: 35.1744
# Current tau: 35.176
# Current tau: 35.1776
# Current tau: 35.1792
# Current tau: 35.180800000000005
# Current tau: 35.1824
# Current tau: 35.184000000000005
# Current tau: 35.1856
# Current tau: 35.187200000000004
# Current tau: 35.1888
# Current tau: 35.190400000000004
# Current tau: 35.192
# Current tau: 35.1936
# Current tau: 35.1952
# Current tau: 35.1968
# Current tau: 35.1984
# Current tau: 35.2
# Current tau: 35.2016
# Current tau: 35.2032
# Current tau: 35.2048
# Current tau: 35.2064
# Current tau: 35.208
# Current tau: 35.2096
# Current tau: 35.211200000000005
# Current tau: 35.2128
# Current tau: 35.214400000000005
# Current tau: 35.216
# Current tau: 35.217600000000004
# Current tau: 35.2192
# Current tau: 35.220800000000004
# Current tau: 35.2224
# Current tau: 35.224000000000004
# Current tau: 35.2256
# Current tau: 35.2272
# Current tau: 35.2288
# Current tau: 35.2304
# Current tau: 35.232
# Current tau: 35.2336
# Current tau: 35.2352
# Current tau: 35.2368
# Current tau: 35.2384
# Current tau: 35.24
# Current tau: 35.2416
# Current tau: 35.2432
# Current tau: 35.244800000000005
# Current tau: 35.2464
# Current tau: 35.248000000000005
# Current tau: 35.2496
# Current tau: 35.251200000000004
# Current tau: 35.2528
# Current tau: 35.254400000000004
# Current tau: 35.256
# Current tau: 35.257600000000004
# Current tau: 35.2592
# Current tau: 35.2608
# Current tau: 35.2624
# Current tau: 35.264
# Current tau: 35.2656
# Current tau: 35.2672
# Current tau: 35.2688
# Current tau: 35.2704
# Current tau: 35.272
# Current tau: 35.2736
# Current tau: 35.275200000000005
# Current tau: 35.2768
# Current tau: 35.278400000000005
# Current tau: 35.28
# Current tau: 35.281600000000005
# Current tau: 35.2832
# Current tau: 35.284800000000004
# Current tau: 35.2864
# Current tau: 35.288000000000004
# Current tau: 35.2896
# Current tau: 35.2912
# ...
# Current a: 1.45356
# Current a: 1.4536200000000001
# Current a: 1.45368
# Current a: 1.45374
# Current a: 1.4538
# Current a: 1.45386
# Current a: 1.45392
# Current a: 1.45398
# Current a: 1.45404
# Current a: 1.4541
# Current a: 1.4541600000000001
# Current a: 1.45422
# Current a: 1.45428
# Current a: 1.45434
# Current a: 1.4544000000000001
# Current a: 1.45446
# Current a: 1.45452
# Current a: 1.45458
# Current a: 1.45464
# Current a: 1.4547
# Current a: 1.45476
# Current a: 1.45482
# Current a: 1.45488
# Current a: 1.4549400000000001
# Current a: 1.455
# Current a: 1.45506
# Current a: 1.45512
# Current a: 1.4551800000000001
# Current a: 1.45524
# Current a: 1.4553
# Current a: 1.45536
# Current a: 1.45542
# Current a: 1.45548
# Current a: 1.45554
# Current a: 1.4556
# Current a: 1.45566
# Current a: 1.4557200000000001
# Current a: 1.45578
# Current a: 1.45584
# Current a: 1.4559
# Current a: 1.4559600000000001
# Current a: 1.45602
# Current a: 1.45608
# Current a: 1.45614
# Current a: 1.4562
# Current a: 1.45626
# Current a: 1.45632
# Current a: 1.45638
# Current a: 1.45644
# Current a: 1.4565000000000001
# Current a: 1.45656
# Current a: 1.45662
# Current a: 1.45668
# Current a: 1.4567400000000001
# Current a: 1.4568
# Current a: 1.45686
# Current a: 1.45692
# Current a: 1.45698
# Current a: 1.4570400000000001
# Current a: 1.4571
# Current a: 1.45716
# Current a: 1.45722
# Current a: 1.4572800000000001
# Current a: 1.45734
# Current a: 1.4574
# Current a: 1.45746
# Current a: 1.45752
# Current a: 1.45758
# Current a: 1.45764
# Current a: 1.4577
# Current a: 1.45776
# Current a: 1.4578200000000001
# Current a: 1.45788
# Current a: 1.45794
# Current a: 1.458
# Current a: 1.4580600000000001
# Current a: 1.45812
# Current a: 1.45818
# Current a: 1.45824
# Current a: 1.4583
# Current a: 1.45836
# Current a: 1.45842
# Current a: 1.45848
# Current a: 1.45854
# Current a: 1.4586000000000001
# Current a: 1.45866
# Current a: 1.45872
# Current a: 1.45878
# Current a: 1.4588400000000001
# Current a: 1.4589
# Current a: 1.45896
# Current a: 1.45902
# Current a: 1.45908
# Current a: 1.45914
# Current a: 1.4592
# Current a: 1.45926
# Current a: 1.45932
# Current a: 1.4593800000000001
# Current a: 1.45944
# Current a: 1.4595
# Current a: 1.45956
# Current a: 1.4596200000000001
# Current a: 1.45968
# Current a: 1.45974
# Current a: 1.4598
# Current a: 1.45986
# Current a: 1.45992
# Current a: 1.45998
# Current a: 1.46004
# Current a: 1.4601
# Current a: 1.4601600000000001
# Current a: 1.46022
# Current a: 1.46028
# Current a: 1.46034
# Current a: 1.4604000000000001
# Current a: 1.46046
# Current a: 1.46052
# Current a: 1.46058
# Current a: 1.46064
# Current a: 1.4607
# Current a: 1.46076
# Current a: 1.46082
# Current a: 1.46088
# Current a: 1.4609400000000001
# Current a: 1.461
# Current a: 1.46106
# Current a: 1.46112
# Current a: 1.4611800000000001
# Current a: 1.46124
# Current a: 1.4613
# Current a: 1.46136
# Current a: 1.46142
# Current a: 1.4614800000000001
# Current a: 1.46154
# Current a: 1.4616
# Current a: 1.46166
# Current a: 1.4617200000000001
# Current a: 1.46178
# Current a: 1.46184
# Current a: 1.4619
# Current a: 1.46196
# Current a: 1.46202
# Current a: 1.46208
# Current a: 1.46214
# Current a: 1.4622
# Current a: 1.4622600000000001
# Current a: 1.46232
# Current a: 1.46238
# Current a: 1.46244
# Current a: 1.4625000000000001
# Current a: 1.46256
# Current a: 1.46262
# Current a: 1.46268
# Current a: 1.46274
# Current a: 1.4628
# Current a: 1.46286
# Current a: 1.46292
# Current a: 1.46298
# Current a: 1.4630400000000001
# Current a: 1.4631
# Current a: 1.46316
# Current a: 1.46322
# Current a: 1.4632800000000001
# Current a: 1.46334
# Current a: 1.4634
# Current a: 1.46346
# Current a: 1.46352
# Current a: 1.46358
# Current a: 1.46364
# Current a: 1.4637
# Current a: 1.46376
# Current a: 1.4638200000000001
# Current a: 1.46388
# Current a: 1.46394
# Current a: 1.464
# Current a: 1.4640600000000001
# Current a: 1.46412
# Current a: 1.46418
# Current a: 1.46424
# Current a: 1.4643
# Current a: 1.46436
# Current a: 1.46442
# Current a: 1.46448
# Current a: 1.46454
# Current a: 1.4646000000000001
# Current a: 1.46466
# Current a: 1.46472
# Current a: 1.46478
# Current a: 1.4648400000000001
# Current a: 1.4649
# Current a: 1.46496
# Current a: 1.46502
# Current a: 1.46508
# Current a: 1.46514
# Current a: 1.4652
# Current a: 1.46526
# Current a: 1.46532
# Current a: 1.4653800000000001
# Current a: 1.46544
# Current a: 1.4655
# Current a: 1.46556
# Current a: 1.4656200000000001
# Current a: 1.46568
# Current a: 1.46574
# Current a: 1.4658
# Current a: 1.46586
# Current a: 1.4659200000000001
# Current a: 1.46598
# Current a: 1.46604
# Current a: 1.4661
# Current a: 1.4661600000000001
# Current a: 1.46622
# Current a: 1.46628
# Current a: 1.46634
# Current a: 1.4664000000000001
# Current a: 1.46646
# Current a: 1.46652
# Current a: 1.46658
# Current a: 1.46664
# Current a: 1.4667000000000001
# Current a: 1.46676
# Current a: 1.46682
# Current a: 1.46688
# Current a: 1.4669400000000001
# Current a: 1.467
# Current a: 1.46706
# Current a: 1.46712
# Current a: 1.46718
# Current a: 1.46724
# Current a: 1.4673
# Current a: 1.46736
# Current a: 1.46742
# Current a: 1.4674800000000001
# Current a: 1.46754
# Current a: 1.4676
# Current a: 1.46766
# Current a: 1.4677200000000001
# Current a: 1.46778
# Current a: 1.46784
# Current a: 1.4679
# Current a: 1.46796
# Current a: 1.46802
# Current a: 1.46808
# Current a: 1.46814
# Current a: 1.4682
# Current a: 1.4682600000000001
# Current a: 1.46832
# Current a: 1.46838
# Current a: 1.46844
# Current a: 1.4685000000000001
# Current a: 1.46856
# Current a: 1.46862
# Current a: 1.46868
# Current a: 1.46874
# Current a: 1.4688
# Current a: 1.46886
# Current a: 1.46892
# Current a: 1.46898
# Current a: 1.4690400000000001
# Current a: 1.4691
# Current a: 1.46916
# Current a: 1.46922
# Current a: 1.4692800000000001
# Current a: 1.46934
# Current a: 1.4694
# Current a: 1.46946
# Current a: 1.46952
# Current a: 1.46958
# Current a: 1.46964
# Current a: 1.4697
# Current a: 1.46976
# Current a: 1.4698200000000001
# Current a: 1.46988
# Current a: 1.46994
# Current a: 1.47
# Current a: 1.4700600000000001
# Current a: 1.47012
# Current a: 1.47018
# Current a: 1.47024
# Current a: 1.4703
# Current a: 1.4703600000000001
# Current a: 1.47042
# Current a: 1.47048
# Current a: 1.47054
# Current a: 1.4706000000000001
# Current a: 1.47066
# Current a: 1.47072
# Current a: 1.47078
# Current a: 1.4708400000000001
# Current a: 1.4709
# Current a: 1.47096
# Current a: 1.47102
# Current a: 1.47108
# Current a: 1.4711400000000001
# Current a: 1.4712
# Current a: 1.47126
# Current a: 1.47132
# Current a: 1.4713800000000001
# Current a: 1.47144
# Current a: 1.4715
# Current a: 1.47156
# Current a: 1.47162
# Current a: 1.47168
# Current a: 1.47174
# Current a: 1.4718
# Current a: 1.47186
# Current a: 1.4719200000000001
# Current a: 1.47198
# Current a: 1.47204
# Current a: 1.4721
# Current a: 1.4721600000000001
# Current a: 1.47222
# Current a: 1.47228
# Current a: 1.47234
# Current a: 1.4724
# Current a: 1.47246
# Current a: 1.47252
# Current a: 1.47258
# Current a: 1.47264
# Current a: 1.4727000000000001
# Current a: 1.47276
# Current a: 1.47282
# Current a: 1.47288
# Current a: 1.4729400000000001
# Current a: 1.473
# Current a: 1.47306
# Current a: 1.47312
# Current a: 1.47318
# Current a: 1.47324
# Current a: 1.4733
# Current a: 1.47336
# Current a: 1.47342
# Current a: 1.4734800000000001
# Current a: 1.47354
# Current a: 1.4736
# Current a: 1.47366
# Current a: 1.4737200000000001
# Current a: 1.47378
# Current a: 1.47384
# Current a: 1.4739
# Current a: 1.47396
# Current a: 1.47402
# Current a: 1.47408
# Current a: 1.47414
# Current a: 1.4742
# Current a: 1.4742600000000001
# Current a: 1.47432
# Current a: 1.47438
# Current a: 1.47444
# Current a: 1.4745000000000001
# Current a: 1.47456
# Current a: 1.47462
# Current a: 1.47468
# Current a: 1.47474
# Current a: 1.4748
# Current a: 1.47486
# Current a: 1.47492
# Current a: 1.47498
# Current a: 1.4750400000000001
# Current a: 1.4751
# Current a: 1.47516
# Current a: 1.47522
# Current a: 1.4752800000000001
# Current a: 1.47534
# Current a: 1.4754
# Current a: 1.47546
# Current a: 1.47552
# Current a: 1.4755800000000001
# Current a: 1.47564
# Current a: 1.4757
# Current a: 1.47576
# Current a: 1.4758200000000001
# Current a: 1.47588
# Current a: 1.47594
# Current a: 1.476
# Current a: 1.47606
# Current a: 1.47612
# Current a: 1.47618
# Current a: 1.47624
# Current a: 1.4763
# Current a: 1.4763600000000001
# Current a: 1.47642
# Current a: 1.47648
# Current a: 1.47654
# Current a: 1.4766000000000001
# Current a: 1.47666
# Current a: 1.47672
# Current a: 1.47678
# Current a: 1.47684
# Current a: 1.4769
# Current a: 1.47696
# Current a: 1.47702
# Current a: 1.47708
# Current a: 1.4771400000000001
# Current a: 1.4772
# Current a: 1.47726
# Current a: 1.47732
# Current a: 1.4773800000000001
# Current a: 1.47744
# Current a: 1.4775
# Current a: 1.47756
# Current a: 1.47762
# Current a: 1.47768
# Current a: 1.47774
# Current a: 1.4778
# Current a: 1.47786
# Current a: 1.4779200000000001
# Current a: 1.47798
# Current a: 1.47804
# Current a: 1.4781
# Current a: 1.4781600000000001
# Current a: 1.47822
# Current a: 1.47828
# Current a: 1.47834
# Current a: 1.4784
# Current a: 1.47846
# Current a: 1.47852
# Current a: 1.47858
# Current a: 1.47864
# Current a: 1.4787000000000001
# Current a: 1.47876
# Current a: 1.47882
# Current a: 1.47888
# Current a: 1.4789400000000001
# Current a: 1.479
# Current a: 1.47906
# Current a: 1.47912
# Current a: 1.47918
# Current a: 1.47924
# Current a: 1.4793
# Current a: 1.47936
# Current a: 1.47942
# Current a: 1.4794800000000001
# Current a: 1.47954
# Current a: 1.4796
# Current a: 1.47966
# Current a: 1.4797200000000001
# Current a: 1.47978
# Current a: 1.47984
# Current a: 1.4799
# Current a: 1.47996
# Current a: 1.4800200000000001
# Current a: 1.48008
# Current a: 1.48014
# Current a: 1.4802
# Current a: 1.4802600000000001
# Current a: 1.48032
# Current a: 1.48038
# Current a: 1.48044
# Current a: 1.4805
# Current a: 1.48056
# Current a: 1.48062
# Current a: 1.48068
# Current a: 1.48074
# Current a: 1.4808000000000001
# Current a: 1.48086
# Current a: 1.48092
# Current a: 1.48098
# Current a: 1.4810400000000001
# Current a: 1.4811
# Current a: 1.48116
# Current a: 1.48122
# Current a: 1.48128
# Current a: 1.48134
# Current a: 1.4814
# Current a: 1.48146
# Current a: 1.48152
# Current a: 1.4815800000000001
# Current a: 1.48164
# Current a: 1.4817
# Current a: 1.48176
# Current a: 1.4818200000000001
# Current a: 1.48188
# Current a: 1.48194
# Current a: 1.482
# Current a: 1.48206
# Current a: 1.48212
# Current a: 1.48218
# Current a: 1.48224
# Current a: 1.4823
# Current a: 1.4823600000000001
# Current a: 1.48242
# Current a: 1.48248
# Current a: 1.48254
# Current a: 1.4826000000000001
# Current a: 1.48266
# Current a: 1.48272
# Current a: 1.48278
# Current a: 1.48284
# Current a: 1.4829
# Current a: 1.48296
# Current a: 1.48302
# Current a: 1.48308
# Current a: 1.4831400000000001
# Current a: 1.4832
# Current a: 1.48326
# Current a: 1.48332
# Current a: 1.4833800000000001
# Current a: 1.48344
# Current a: 1.4835
# Current a: 1.48356
# Current a: 1.48362
# Current a: 1.48368
# Current a: 1.48374
# Current a: 1.4838
# Current a: 1.48386
# Current a: 1.4839200000000001
# Current a: 1.48398
# Current a: 1.48404
# Current a: 1.4841
# Current a: 1.4841600000000001
# Current a: 1.48422
# Current a: 1.48428
# Current a: 1.48434
# Current a: 1.4844
# Current a: 1.4844600000000001
# Current a: 1.48452
# Current a: 1.48458
# Current a: 1.48464
# Current a: 1.4847000000000001
# Current a: 1.48476
# Current a: 1.48482
# Current a: 1.48488
# Current a: 1.48494
# Current a: 1.485
# Current a: 1.48506
# Current a: 1.48512
# Current a: 1.48518
# Current a: 1.4852400000000001
# Current a: 1.4853
# Current a: 1.48536
# Current a: 1.48542
# Current a: 1.4854800000000001
# Current a: 1.48554
# Current a: 1.4856
# Current a: 1.48566
# Current a: 1.48572
# Current a: 1.48578
# Current a: 1.48584
# Current a: 1.4859
# Current a: 1.48596
# Current a: 1.4860200000000001
# Current a: 1.48608
# Current a: 1.48614
# Current a: 1.4862
# Current a: 1.4862600000000001
# Current a: 1.48632
# Current a: 1.48638
# Current a: 1.48644
# Current a: 1.4865
# Current a: 1.48656
# Current a: 1.48662
# Current a: 1.48668
# Current a: 1.48674
# Current a: 1.4868000000000001
# Current a: 1.48686
# Current a: 1.48692
# Current a: 1.48698
# Current a: 1.4870400000000001
# Current a: 1.4871
# Current a: 1.48716
# Current a: 1.48722
# Current a: 1.48728
# Current a: 1.48734
# Current a: 1.4874
# Current a: 1.48746
# Current a: 1.48752
# Current a: 1.4875800000000001
# Current a: 1.48764
# Current a: 1.4877
# Current a: 1.48776
# Current a: 1.4878200000000001
# Current a: 1.48788
# Current a: 1.48794
# Current a: 1.488
# Current a: 1.48806
# Current a: 1.48812
# Current a: 1.48818
# Current a: 1.48824
# Current a: 1.4883
# Current a: 1.4883600000000001
# Current a: 1.48842
# Current a: 1.48848
# Current a: 1.48854
# Current a: 1.4886000000000001
# Current a: 1.48866
# Current a: 1.48872
# Current a: 1.48878
# Current a: 1.48884
# Current a: 1.4889000000000001
# Current a: 1.48896
# Current a: 1.48902
# Current a: 1.48908
# Current a: 1.4891400000000001
# Current a: 1.4892
# Current a: 1.48926
# Current a: 1.48932
# Current a: 1.4893800000000001
# Current a: 1.48944
# Current a: 1.4895
# Current a: 1.48956
# Current a: 1.48962
# Current a: 1.4896800000000001
# Current a: 1.48974
# Current a: 1.4898
# Current a: 1.48986
# Current a: 1.4899200000000001
# Current a: 1.48998
# Current a: 1.49004
# Current a: 1.4901
# Current a: 1.49016
# Current a: 1.49022
# Current a: 1.49028
# Current a: 1.49034
# Current a: 1.4904
# Current a: 1.4904600000000001
# Current a: 1.49052
# Current a: 1.49058
# Current a: 1.49064
# Current a: 1.4907000000000001
# Current a: 1.49076
# Current a: 1.49082
# Current a: 1.49088
# Current a: 1.49094
# Current a: 1.491
# Current a: 1.49106
# Current a: 1.49112
# Current a: 1.49118
# Current a: 1.4912400000000001
# Current a: 1.4913
# Current a: 1.49136
# Current a: 1.49142
# Current a: 1.4914800000000001
# Current a: 1.49154
# Current a: 1.4916
# Current a: 1.49166
# Current a: 1.49172
# Current a: 1.49178
# Current a: 1.49184
# Current a: 1.4919
# Current a: 1.49196
# Current a: 1.4920200000000001
# Current a: 1.49208
# Current a: 1.49214
# Current a: 1.4922
# Current a: 1.4922600000000001
# Current a: 1.49232
# Current a: 1.49238
# Current a: 1.49244
# Current a: 1.4925
# Current a: 1.49256
# Current a: 1.49262
# Current a: 1.49268
# Current a: 1.49274
# Current a: 1.4928000000000001
# Current a: 1.49286
# Current a: 1.49292
# Current a: 1.49298
# Current a: 1.4930400000000001
# Current a: 1.4931
# Current a: 1.49316
# Current a: 1.49322
# Current a: 1.49328
# Current a: 1.4933400000000001
# Current a: 1.4934
# Current a: 1.49346
# Current a: 1.49352
# Current a: 1.4935800000000001
# Current a: 1.49364
# Current a: 1.4937
# Current a: 1.49376
# Current a: 1.4938200000000001
# Current a: 1.49388
# Current a: 1.49394
# Current a: 1.494
# Current a: 1.49406
# Current a: 1.4941200000000001
# Current a: 1.49418
# Current a: 1.49424
# Current a: 1.4943
# Current a: 1.4943600000000001
# Current a: 1.49442
# Current a: 1.49448
# Current a: 1.49454
# Current a: 1.4946
# Current a: 1.49466
# Current a: 1.49472
# Current a: 1.49478
# Current a: 1.49484
# Current a: 1.4949000000000001
# Current a: 1.49496
# Current a: 1.49502
# Current a: 1.49508
# Current a: 1.4951400000000001
# Current a: 1.4952
# Current a: 1.49526
# Current a: 1.49532
# Current a: 1.49538
# Current a: 1.49544
# Current a: 1.4955
# Current a: 1.49556
# Current a: 1.49562
# Current a: 1.4956800000000001
# Current a: 1.49574
# Current a: 1.4958
# Current a: 1.49586
# Current a: 1.4959200000000001
# Current a: 1.49598
# Current a: 1.49604
# Current a: 1.4961
# Current a: 1.49616
# Current a: 1.49622
# Current a: 1.49628
# Current a: 1.49634
# Current a: 1.4964
# Current a: 1.4964600000000001
# Current a: 1.49652
# Current a: 1.49658
# Current a: 1.49664
# Current a: 1.4967000000000001
# Current a: 1.49676
# Current a: 1.49682
# Current a: 1.49688
# Current a: 1.49694
# Current a: 1.497
# Current a: 1.49706
# Current a: 1.49712
# Current a: 1.49718
# Current a: 1.4972400000000001
# Current a: 1.4973
# Current a: 1.49736
# Current a: 1.49742
# Current a: 1.4974800000000001
# Current a: 1.49754
# Current a: 1.4976
# Current a: 1.49766
# Current a: 1.49772
# Current a: 1.4977800000000001
# Current a: 1.49784
# Current a: 1.4979
# Current a: 1.49796
# Current a: 1.4980200000000001
# Current a: 1.49808
# Current a: 1.49814
# Current a: 1.4982
# Current a: 1.4982600000000001
# Current a: 1.49832
# Current a: 1.49838
# Current a: 1.49844
# Current a: 1.4985
# Current a: 1.4985600000000001
# Current a: 1.49862
# Current a: 1.49868
# Current a: 1.49874
# Current a: 1.4988000000000001
# Current a: 1.49886
# Current a: 1.49892
# Current a: 1.49898
# Current a: 1.49904
# Current a: 1.4991
# Current a: 1.49916
# Current a: 1.49922
# Current a: 1.49928
# Current a: 1.4993400000000001
# Current a: 1.4994
# Current a: 1.49946
# Current a: 1.49952
# Current a: 1.4995800000000001
# Current a: 1.49964
# Current a: 1.4997
# Current a: 1.49976
# Current a: 1.49982
# Current a: 1.49988
# Current a: 1.49994
